# %%
import os
from shutil import unpack_archive

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
unpack_archive("/content/drive/MyDrive/Colab Notebooks/RZ/Demo Day/OCR.zip")

# %%
for dirname, _, filenames in os.walk('./ImageAndXML_Data'):
    filepath = dirname
    list_filename = filenames
    # for filename in filenames:
    #    print(os.path.join(dirname, filename))

# %% [markdown]
# # Accessing the directory with all the files and all the filenames

# %%
print(filepath)
print(list_filename)
# Out:
# ./ImageAndXML_Data
# ['2041532206_gt.xml', 'ti16400164.tif', '99380808_0809_gt.xml', '11002591_ocr.xml', '2063610122_ocr.xml', '2063610122.tif', '00555341.tif', '89703081_gt.xml', '2080705096_gt.xml', '80233716_gt.xml', '2042525639_ocr.xml', '86463030_ocr.xml', '2072957946_ocr.xml', '82898529_gt.xml', '0060203682_gt.xml', '87021931_ocr.xml', '2041597671_2041597672_ocr.xml', '526509181+-9181_gt.xml', '86018092.tif', '2041222828_ocr.xml', '0060076201.tif', '2051801680.tif', '2043342113_ocr.xml', '2041532206.tif', '2029377295.tif', '2083197818_7819.tif', '91543951_3952_ocr.xml', '2029377295_ocr.xml', '0000223278_ocr.xml', '2063322469_gt.xml', '0060027402_gt.xml', 'ti16310545.tif', '87147464.tif', '2063650388_ocr.xml', '2040687664_gt.xml', '2065216982_gt.xml', '2044696237_gt.xml', '83565599.tif', '87803300_gt.xml', '2040345058.tif', '2063235029.tif', '0001136521.tif', '526450353+-0353.tif', '0060094811_gt.xml', '500234635+-4635_ocr.xml', '2063576893_ocr.xml', '2070584510_gt.xml', '2029370464.tif', '2085538660_gt.xml', '2074484114_ocr.xml', '0060076899_ocr.xml', '86087318_7321_gt.xml', '92873320_3322.tif', '93216067_ocr.xml', '2044688196.tif', '2063235029_ocr.xml', '2084021799.tif', '83542431_ocr.xml', '2043396778.tif', '2029377288_ocr.xml', '99380808_0809.tif', '2063209074_9077.tif', 'ti16310545_gt.xml', '0071033192_ocr.xml', '83553533.tif', '2023527344_gt.xml', '2085699092.tif', '03725237_ocr.xml', '2501336275_2501336276_gt.xml', '11237682_11237683.tif', '2071021272_ocr.xml', '2071386322.tif', '2065466615_gt.xml', '2084020376_ocr.xml', '2015064568.tif', '2505118349_gt.xml', '580108985+-8990_gt.xml', '2070424009_gt.xml', '80233633_ocr.xml', 'ti16310917_ocr.xml', '2085539738.tif', '80211567_ocr.xml', '2044444071.tif', '518284417+-4420_gt.xml', '0060047831_gt.xml', 'ti31689150_ocr.xml', '80211548.tif', '2064339433_gt.xml', '0060027778.tif', 'ti17120498_gt.xml', '503116428+-6428_ocr.xml', '82898533_ocr.xml', '2084022627_gt.xml', '83565599_ocr.xml', '2084022482_gt.xml', '2064225959_ocr.xml', '2084021799_ocr.xml', '2001200321.tif', 'CTRCONTRACTS017922-7_ocr.xml', '2024485248_ocr.xml', 'ti16131011_1013.tif', '2072860354_ocr.xml', '2063576893.tif', '500234635+-4635_gt.xml', '2501336291_2501336296_gt.xml', '2040345061.tif', 'ti16311096.tif', 'ti17120743.tif', '2063610122_gt.xml', '82898406_gt.xml', '2041954112.tif', '0060099385_ocr.xml', '86087013_ocr.xml', '2028704426_ocr.xml', '2026000180.tif', '2044146550_ocr.xml', '0001144288.tif', '2072957848_gt.xml', 'ti16400388.tif', '2063610071_gt.xml', '2028674067.tif', '0060085465.tif', '89000106_gt.xml', '2070424009_ocr.xml', '0060094811.tif', '86087495_7496_gt.xml', '0060204458.tif', '2029370271_ocr.xml', '2055018950.tif', '2044146550_gt.xml', '1000031514_gt.xml', '2028726871_gt.xml', '91575506_5509.tif', '2084022136_ocr.xml', '514218180+-8181_gt.xml', '92185547.tif', '2064978624.tif', '514802406+-2409.tif', '2030403394_2030403397_ocr.xml', 'ti31689150_gt.xml', '11002339_gt.xml', '2041531738_1761.tif', '500125099+-5100_ocr.xml', '518253610+-3615_ocr.xml', '2029138584_ocr.xml', '91668026_ocr.xml', '2501336486.tif', '2070750524_gt.xml', '86618995.tif', '0060076899.tif', '2071382979_ocr.xml', '2056446070_ocr.xml', '518232342+-2342_gt.xml', '0060060466.tif', 'CTRCONTRACTS017947-7_gt.xml', '524483561+-3562_gt.xml', '00921466.tif', '2030305992.tif', '2063576893_gt.xml', '2501336351_ocr.xml', '96403982.tif', '0060203682.tif', '0001139716_gt.xml', '500125481+-5481_gt.xml', '0060207567.tif', '2065364917.tif', '2051801680_ocr.xml', '83096187.tif', '80702654_gt.xml', 'ti16310917.tif', '0060053785.tif', '96063482.tif', '0060031680_gt.xml', '0060087309_gt.xml', '80702654_ocr.xml', '2083197453_ocr.xml', '2073684342.tif', '2040345061_ocr.xml', '513265741_513265875_ocr.xml', '2040735287_ocr.xml', '2084022002_gt.xml', '96063504.tif', 'ti16801274_ocr.xml', '0060060439_ocr.xml', '92891078_1079_ocr.xml', 'ti16532219_2220_gt.xml', '89703081_ocr.xml', '2084022300.tif', 'ti16310260_gt.xml', 'ti17120027_gt.xml', '2084024707.tif', '202920 ...

# %% [markdown]
# # XML Parsing
#
# XML parsing in python is done either by using **lxml parser along with beautiful soup or using elementtree library**. Choose the one which suits your needs better.
#
# Our aim is to read the text data from XML file and put the information of all the files in a text file. First we read a file and try to get the text from a single file then we loop over all the files to get the text from all the files.

# %%
#For making list of all the *_OCR.xml files in the data folder use glob or fnmatch+os.listdir()
import fnmatch

file_list = []
for file in list_filename:
    if fnmatch.fnmatch(file,'*_ocr.xml'):
        file_list.append(file)

# %%
#Let's try to open one file and see how well does it help us:
with open(os.path.join(dirname,file_list[0]),'r') as f:
    data = f.read()
f.close()

# %%
print(data)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <PcGts xmlns="http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15">
#   <Metadata>
#     <Creator>ABBYY FineReader Engine 11 + alto2page.xslt 2018.11.09</Creator>
#     <Created>2019-01-23T00:00:00</Created>
#     <LastChange>2019-01-23T00:00:00</LastChange>
#   </Metadata>
#   <Page imageFilename="11002591.tif" imageHeight="1000" imageWidth="771">
#     <TextRegion id="Page1_TopMargin">
#       <Property key="Margin" value="Top"/>
#       <Coords points="0,0 771,0 771,28 0,28"/>
#     </TextRegion>
#     <TextRegion id="Page1_LeftMargin">
#       <Property key="Margin" value="Left"/>
#       <Coords points="0,28 51,28 51,902 0,902"/>
#     </TextRegion>
#     <TextRegion id="Page1_RightMargin">
#       <Property key="Margin" value="Right"/>
#       <Coords points="751,28 771,28 771,902 751,902"/>
#     </TextRegion>
#     <TextRegion id="Page1_BottomMargin">
#       <Property key="Margin" value="Bottom"/>
#       <Coords points="0,902 771,902 771,1000 0,1000"/>
#     </TextRegion>
#     <TextRegion id="Page1_PrintSpace">
#       <Property key="Margin" value=""/>
#       <Coords points="51,28 751,28 751,902 51,902"/>
#     </TextRegion>
#     <TextRegion id="Page1_Block1">
#       <Property key="language" value="en-US"/>
#       <Coords points="55,28 113,28 113,36 55,36"/>
#       <TextLine id="Page1_Block1_l1">
#         <Coords points="58,29 90,29 90,33 58,33"/>
#         <Word id="Page1_Block1_l1_w1">
#           <Coords points="58,29 70,29 70,33 58,33"/>
#           <TextEquiv conf="0.473333329">
#             <Unicode>8**</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block1_l1_w2">
#           <Coords points="72,29 90,29 90,33 72,33"/>
#           <TextEquiv conf="0.6075000167">
#             <Unicode>ICO^</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block2">
#       <Property key="language" value="en-US"/>
#       <Coords points="87,63 106,63 106,69 87,69"/>
#       <TextLine id="Page1_Block2_l1">
#         <Coords points="91,63 101,63 101,67 91,67"/>
#         <Word id="Page1_Block2_l1_w1">
#           <Coords points="91,64 93,64 93,67 91,67"/>
#           <TextEquiv conf="0.150000006">
#             <Unicode>f</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block2_l1_w2">
#           <Coords points="99,63 101,63 101,66 99,66"/>
#           <TextEquiv conf="0.2599999905">
#             <Unicode>*</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <ImageRegion id="Page1_Block3">
#       <Coords points="252,31 562,31 562,98 252,98"/>
#     </ImageRegion>
#     <TextRegion id="Page1_Block4">
#       <Property key="language" value="en-US"/>
#       <Coords points="581,51 656,51 656,81 581,81"/>
#       <TextLine id="Page1_Block4_l1">
#         <Coords points="585,52 651,52 651,60 585,60"/>
#         <Word id="Page1_Block4_l1_w1">
#           <Coords points="585,52 627,52 627,59 585,59"/>
#           <TextEquiv conf="0.6342856884">
#             <Unicode>INVOICE</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block4_l1_w2">
#           <Coords points="633,53 651,53 651,60 633,60"/>
#           <TextEquiv conf="0.5433333516">
#             <Unicode>NO.</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#       <TextLine id="Page1_Block4_l2">
#         <Coords points="602,69 651,69 651,79 602,79"/>
#         <Word id="Page1_Block4_l2_w1">
#           <Coords points="602,69 651,69 651,79 602,79"/>
#           <TextEquiv conf="0.4099999964">
#             <Unicode>B-07025</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block5">
#       <Property key="language" value="en-US"/>
#       <Coords points="54,104 104,104 104,112 54,112"/>
#       <TextLine id="Page1_Block5_l1">
#         <Coords points="57,104 99,104 99,110 57,110"/>
#         <Word id="Page1_Block5_l1_w1">
#           <Coords points="57,104 82,104 82,110 57,110"/>
#           <TextEquiv conf="0.337500006">
#             <Unicode>SOLO</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block5_l1_w2">
#           <Coords points="87,104 99,104 99,109 87,109"/>
#           <TextEquiv conf="0.3799999952">
#             <Unicode>TO</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block6">
#       <Property key="language" value="en-US"/>
#       <Coords points="132,113 373,113 373,125 132,125"/>
#       <TextLine id="Page1_Block6_l1">
#         <Coords points="136,114 368,114 368,123 136,123"/>
#         <Word id="Page1_Block6_l1_w1">
#           <Coords points="136,115 157,115 157,123 136,123"/>
#           <TextEquiv conf="0.4066666663">
#             <Unicode>The</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block6_l1_w2">
#           <Coords points="165,114 215,114 215,123 165,123"/>
#           <TextEquiv conf="0.4728571475">
#             <Unicode>Council</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block6_l1_w3">
#           <Coords points="224,115 245,115 245,123 224,123"/>
#           <TextEquiv conf="0.3199999928">
#             <Unicode>for</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block6_l1_w4">
#           <Coords points="253,115 303,115 303,123 253,123"/>
#           <TextEquiv conf="0.4257142842">
#             <Unicode>Tobacco</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block6_l1_w5">
#           <Coords points="312,114 368,114 368,123 312,123"/>
#           <TextEquiv conf="0.4600000083">
#             <Unicode>Research</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block7">
#       <Property key="language" value="en-US"/>
#       <Coords points="481,102 511,102 511,111 481,111"/>
#       <TextLine id="Page1_Block7_l1">
#         <Coords points="482,104 506,104 506,109 482,109"/>
#         <Word id="Page1_Block7_l1_w1">
#           <Coords points="482,104 506,104 506,109 482,109"/>
#           <TextEquiv conf="0.2700000107">
#             <Unicode>DATE</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block8">
#       <Property key="language" value="en-US"/>
#       <Coords points="490,111 548,111 548,126 490,126"/>
#       <TextLine id="Page1_Block8_l1">
#         <Coords points="493,111 543,111 543,124 493,124"/>
#         <Word id="Page1_Block8_l1_w1">
#           <Coords points="493,111 543,111 543,124 493,124"/>
#           <TextEquiv conf="0.4842857122">
#             <Unicode>7-13-67</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block9">
#       <Property key="language" value="en-US"/>
#       <Coords points="596,102 669,102 669,126 596,126"/>
#       <TextLine id="Page1_Block9_l1">
#         <Coords points="599,103 664,103 664,110 599,110"/>
#         <Word id="Page1_Block9_l1_w1">
#           <Coords points="599,103 633,103 633,110 599,110"/>
#           <TextEquiv conf="0.1933333278">
#             <Unicode>crcoiV</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block9_l1_w2">
#           <Coords points="638,103 664,103 664,110 638,110"/>
#           <TextEquiv conf="0.25">
#             <Unicode>do6c</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#       <TextLine id="Page1_Block9_l2">
#         <Coords points="623,113 651,113 651,124 623,124"/>
#         <Word id="Page1_Block9_l2_w1">
#           <Coords points="623,113 651,113 651,124 623,124"/>
#           <TextEquiv conf="0.5224999785">
#             <Unicode>033B</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block10">
#       <Property key="ComposedBlock" value="Page1_Block11 Page1_Block12 Page1_Block13 Page1_Block14 Page1_Block15 Page1_Block16 Page1_Block17 Page1_Block18 Page1_Block19 Page1_Block20 Page1_Block21 Page1_Block22 Page1_Block23"/>
#       <Coords points="56,126 751,126 751,266 56,266"/>
#     </TextRegion>
#     <TextRegion id="Page1_Block11">
#       <Property key="language" value="en-US"/>
#       <Coords points="56,126 477,126 477,157 56,157"/>
#       <TextLine id="Page1_Block11_l1">
#         <Coords points="57,128 473,128 473,137 57,137"/>
#         <Word id="Page1_Block11_l1_w1">
#           <Coords points="57,128 103,128 103,137 57,137"/>
#           <TextEquiv conf="0.2771428525">
#             <Unicode>XEBXiss</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block11_l1_w2">
#           <Coords points="236,128 239,128 239,136 236,136"/>
#           <TextEquiv conf="0.1599999964">
#             <Unicode>:</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block11_l1_w3">
#           <Coords points="406,128 423,128 423,136 406,136"/>
#           <TextEquiv conf="0.1550000012">
#             <Unicode>rr</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#       <TextLine id="Page1_Block11_l2">
#         <Coords points="136,139 252,139 252,152 136,152"/>
#         <Word id="Page1_Block11_l2_w1">
#           <Coords points="136,139 157,139 157,152 136,152"/>
#           <TextEquiv conf="0.3366666734">
#             <Unicode>633</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block11_l2_w2">
#           <Coords points="165,141 201,141 201,150 165,150"/>
#           <TextEquiv conf="0.3359999955">
#             <Unicode>Third</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block11_l2_w3">
#           <Coords points="208,142 252,142 252,150 208,150"/>
#           <TextEquiv conf="0.6833333373">
#             <Unicode>Avenue</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block12">
#       <Property key="language" value="en-US"/>
#       <Coords points="477,126 751,126 751,157 477,157"/>
#       <TextLine id="Page1_Block12_l1">
#         <Coords points="492,143 571,143 571,154 492,154"/>
#         <Word id="Page1_Block12_l1_w1">
#           <Coords points="492,143 513,143 513,152 492,152"/>
#           <TextEquiv conf="0.6933333278">
#             <Unicode>Net</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block12_l1_w2">
#           <Coords points="522,143 535,143 535,153 522,153"/>
#           <TextEquiv conf="0.4149999917">
#             <Unicode>30</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block12_l1_w3">
#           <Coords points="543,143 571,143 571,154 543,154"/>
#           <TextEquiv conf="0.5174999833">
#             <Unicode>Days</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block13">
#       <Property key="language" value="en-US"/>
#       <Coords points="56,157 477,157 477,183 56,183"/>
#       <TextLine id="Page1_Block13_l1">
#         <Coords points="136,171 311,171 311,181 136,181"/>
#         <Word id="Page1_Block13_l1_w1">
#           <Coords points="136,171 157,171 157,180 136,180"/>
#           <TextEquiv conf="0.4766666591">
#             <Unicode>New</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block13_l1_w2">
#           <Coords points="165,171 199,171 199,181 165,181"/>
#           <TextEquiv conf="0.400000006">
#             <Unicode>York,</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block13_l1_w3">
#           <Coords points="209,171 230,171 230,180 209,180"/>
#           <TextEquiv conf="0.3566666543">
#             <Unicode>New</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block13_l1_w4">
#           <Coords points="238,171 267,171 267,180 238,180"/>
#           <TextEquiv conf="0.5325000286">
#             <Unicode>York</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block13_l1_w5">
#           <Coords points="275,171 311,171 311,180 275,180"/>
#           <TextEquiv conf="0.7620000243">
#             <Unicode>10017</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block14">
#       <Property key="language" value="en-US"/>
#       <Coords points="56,183 477,183 477,211 56,211"/>
#       <TextLine id="Page1_Block14_l1">
#         <Coords points="136,198 346,198 346,207 136,207"/>
#         <Word id="Page1_Block14_l1_w1">
#           <Coords points="136,198 206,198 206,207 136,207"/>
#           <TextEquiv conf="0.5350000262">
#             <Unicode>Attention:</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block14_l1_w2">
#           <Coords points="223,198 243,198 243,207 223,207"/>
#           <TextEquiv conf="0.6266666651">
#             <Unicode>Dr.</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block14_l1_w3">
#           <Coords points="253,198 265,198 265,206 253,206"/>
#           <TextEquiv conf="0.625">
#             <Unicode>R.</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block14_l1_w4">
#           <Coords points="275,198 287,198 287,206 275,206"/>
#           <TextEquiv conf="0.4300000072">
#             <Unicode>C.</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block14_l1_w5">
#           <Coords points="296,198 346,198 346,206 296,206"/>
#           <TextEquiv conf="0.6057142615">
#             <Unicode>Hockett</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block15">
#       <Property key="language" value="en-US"/>
#       <Coords points="477,183 751,183 751,211 477,211"/>
#       <TextLine id="Page1_Block15_l1">
#         <Coords points="481,185 544,185 544,190 481,190"/>
#         <Word id="Page1_Block15_l1_w1">
#           <Coords points="481,185 544,185 544,190 481,190"/>
#           <TextEquiv conf="0.5672727227">
#             <Unicode>DESTINATION</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block16">
#       <Property key="language" value="en-US"/>
#       <Coords points="56,211 353,211 353,239 56,239"/>
#       <TextLine id="Page1_Block16_l1">
#         <Coords points="57,211 307,211 307,217 57,217"/>
#         <Word id="Page1_Block16_l1_w1">
#           <Coords points="57,211 118,211 118,217 57,217"/>
#           <TextEquiv conf="0.6240000129">
#             <Unicode>CUSTOMER’S</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block16_l1_w2">
#           <Coords points="123,211 156,211 156,216 123,216"/>
#           <TextEquiv conf="0.4140000045">
#             <Unicode>ORDER</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block16_l1_w3">
#           <Coords points="160,211 176,211 176,217 160,217"/>
#           <TextEquiv conf="0.3766666651">
#             <Unicode>NO.</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block16_l1_w4">
#           <Coords points="271,211 287,211 287,217 271,217"/>
#           <TextEquiv conf="0.400000006">
#             <Unicode>B/L</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block16_l1_w5">
#           <Coords points="292,211 307,211 307,217 292,217"/>
#           <TextEquiv conf="0.3966666758">
#             <Unicode>NO.</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#       <TextLine id="Page1_Block16_l2">
#         <Coords points="63,225 201,225 201,235 63,235"/>
#         <Word id="Page1_Block16_l2_w1">
#           <Coords points="63,225 92,225 92,233 63,233"/>
#           <TextEquiv conf="0.5174999833">
#             <Unicode>BNPI</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block16_l2_w2">
#           <Coords points="93,225 113,225 113,234 93,234"/>
#           <TextEquiv conf="0.7466666698">
#             <Unicode>-19</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block16_l2_w3">
#           <Coords points="115,225 164,225 164,235 115,235"/>
#           <TextEquiv conf="0.3485714197">
#             <Unicode>5-Subst</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block16_l2_w4">
#           <Coords points="166,225 171,225 171,233 166,233"/>
#           <TextEquiv conf="0.9300000072">
#             <Unicode>i</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block16_l2_w5">
#           <Coords points="172,225 193,225 193,233 172,233"/>
#           <TextEquiv conf="0.5500000119">
#             <Unicode>tut</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block16_l2_w6">
#           <Coords points="194,227 201,227 201,233 194,233"/>
#           <TextEquiv conf="0.1800000072">
#             <Unicode>e</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block17">
#       <Property key="language" value="en-US"/>
#       <Coords points="393,211 477,211 477,239 393,239"/>
#       <TextLine id="Page1_Block17_l1">
#         <Coords points="393,211 442,211 442,218 393,218"/>
#         <Word id="Page1_Block17_l1_w1">
#           <Coords points="393,211 394,211 394,218 393,218"/>
#           <TextEquiv conf="1">
#             <Unicode>|</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block17_l1_w2">
#           <Coords points="398,212 413,212 413,217 398,217"/>
#           <TextEquiv conf="0.1366666704">
#             <Unicode>O/L</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block17_l1_w3">
#           <Coords points="417,212 442,212 442,217 417,217"/>
#           <TextEquiv conf="0.5350000262">
#             <Unicode>WOT.</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block18">
#       <Property key="language" value="en-US"/>
#       <Coords points="56,239 165,239 165,266 56,266"/>
#       <TextLine id="Page1_Block18_l1">
#         <Coords points="57,239 83,239 83,243 57,243"/>
#         <Word id="Page1_Block18_l1_w1">
#           <Coords points="57,239 83,239 83,243 57,243"/>
#           <TextEquiv conf="0.448333323">
#             <Unicode>F.O.B.</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block19">
#       <Property key="language" value="en-US"/>
#       <Coords points="165,239 353,239 353,266 165,266"/>
#       <TextLine id="Page1_Block19_l1">
#         <Coords points="170,239 253,239 253,243 170,243"/>
#         <Word id="Page1_Block19_l1_w1">
#           <Coords points="170,239 189,239 189,243 170,243"/>
#           <TextEquiv conf="0.4699999988">
#             <Unicode>CAR</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block19_l1_w2">
#           <Coords points="193,239 222,239 222,243 193,243"/>
#           <TextEquiv conf="0.4583333433">
#             <Unicode>INTLS.</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block19_l1_w3">
#           <Coords points="227,239 233,239 233,243 227,243"/>
#           <TextEquiv conf="0.5699999928">
#             <Unicode>ft</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block19_l1_w4">
#           <Coords points="237,239 253,239 253,243 237,243"/>
#           <TextEquiv conf="0.2666666806">
#             <Unicode>NO.</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block20">
#       <Property key="language" value="en-US"/>
#       <Coords points="353,239 393,239 393,266 353,266"/>
#       <TextLine id="Page1_Block20_l1">
#         <Coords points="358,238 392,238 392,244 358,244"/>
#         <Word id="Page1_Block20_l1_w1">
#           <Coords points="358,238 392,238 392,244 358,244"/>
#           <TextEquiv conf="0.2028571367">
#             <Unicode>SHIPPIP</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block21">
#       <Property key="language" value="en-US"/>
#       <Coords points="393,239 536,239 536,266 393,266"/>
#       <TextLine id="Page1_Block21_l1">
#         <Coords points="393,239 434,239 434,243 393,243"/>
#         <Word id="Page1_Block21_l1_w1">
#           <Coords points="393,239 402,239 402,243 393,243"/>
#           <TextEquiv conf="0.2649999857">
#             <Unicode>IO</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block21_l1_w2">
#           <Coords points="407,239 434,239 434,243 407,243"/>
#           <TextEquiv conf="0.5299999714">
#             <Unicode>POINT</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block22">
#       <Property key="language" value="en-US"/>
#       <Coords points="536,239 644,239 644,266 536,266"/>
#       <TextLine id="Page1_Block22_l1">
#         <Coords points="540,239 616,239 616,244 540,244"/>
#         <Word id="Page1_Block22_l1_w1">
#           <Coords points="540,239 558,239 558,244 540,244"/>
#           <TextEquiv conf="0.003333333414">
#             <Unicode>PNL</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block22_l1_w2">
#           <Coords points="562,239 595,239 595,244 562,244"/>
#           <TextEquiv conf="0.6019999981">
#             <Unicode>ORDER</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block22_l1_w3">
#           <Coords points="600,239 616,239 616,244 600,244"/>
#           <TextEquiv conf="0.5">
#             <Unicode>NO.</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block23">
#       <Property key="language" value="en-US"/>
#       <Coords points="644,239 751,239 751,266 644,266"/>
#       <TextLine id="Page1_Block23_l1">
#         <Coords points="650,239 719,239 719,244 650,244"/>
#         <Word id="Page1_Block23_l1_w1">
#           <Coords points="650,239 674,239 674,244 650,244"/>
#           <TextEquiv conf="0.4724999964">
#             <Unicode>DATE</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block23_l1_w2">
#           <Coords points="679,239 719,239 719,244 679,244"/>
#           <TextEquiv conf="0.5028571486">
#             <Unicode>SHIPPED</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block24">
#       <Property key="language" value="en-US"/>
#       <Coords points="179,267 274,267 274,274 179,274"/>
#       <TextLine id="Page1_Block24_l1">
#         <Coords points="182,267 269,267 269,272 182,272"/>
#         <Word id="Page1_Block24_l1_w1">
#           <Coords points="182,267 269,267 269,272 182,272"/>
#           <TextEquiv conf="0.4211111069">
#             <Unicode>COMMODITY</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block25">
#       <Property key="language" value="en-US"/>
#       <Coords points="59,287 393,287 393,345 59,345"/>
#       <TextLine id="Page1_Block25_l1">
#         <Coords points="63,290 172,290 172,301 63,301"/>
#         <Word id="Page1_Block25_l1_w1">
#           <Coords points="63,291 113,291 113,301 63,301"/>
#           <TextEquiv conf="0.5942857265">
#             <Unicode>Project</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block25_l1_w2">
#           <Coords points="121,291 129,291 129,300 121,300"/>
#           <TextEquiv conf="0.3799999952">
#             <Unicode>Y</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block25_l1_w3">
#           <Coords points="137,290 172,290 172,301 137,301"/>
#           <TextEquiv conf="0.5133333206">
#             <Unicode>1^0153</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#       <TextLine id="Page1_Block25_l2">
#         <Coords points="64,318 325,318 325,328 64,328"/>
#         <Word id="Page1_Block25_l2_w1">
#           <Coords points="64,319 121,319 121,327 64,327"/>
#           <TextEquiv conf="0.53125">
#             <Unicode>Research</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block25_l2_w2">
#           <Coords points="129,320 143,320 143,327 129,327"/>
#           <TextEquiv conf="0.6299999952">
#             <Unicode>on</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block25_l2_w3">
#           <Coords points="151,318 200,318 200,327 151,327"/>
#           <TextEquiv conf="0.5571428537">
#             <Unicode>Methods</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block25_l2_w4">
#           <Coords points="209,318 223,318 223,326 209,326"/>
#           <TextEquiv conf="0.3899999857">
#             <Unicode>of</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block25_l2_w5">
#           <Coords points="231,318 296,318 296,328 231,328"/>
#           <TextEquiv conf="0.6277777553">
#             <Unicode>Measuring</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block25_l2_w6">
#           <Coords points="304,318 325,318 325,326 304,326"/>
#           <TextEquiv conf="0.400000006">
#             <Unicode>the</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#       <TextLine id="Page1_Block25_l3">
#         <Coords points="63,331 390,331 390,343 63,343"/>
#         <Word id="Page1_Block25_l3_w1">
#           <Coords points="63,332 136,332 136,343 63,343"/>
#           <TextEquiv conf="0.4830000103">
#             <Unicode>Deposition</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block25_l3_w2">
#           <Coords points="144,332 158,332 158,340 144,340"/>
#           <TextEquiv conf="0.6600000262">
#             <Unicode>of</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block25_l3_w3">
#           <Coords points="166,331 216,331 216,340 166,340"/>
#           <TextEquiv conf="0.495714277">
#             <Unicode>Inhaled</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block25_l3_w4">
#           <Coords points="224,331 289,331 289,342 224,342"/>
#           <TextEquiv conf="0.6355555654">
#             <Unicode>Cigarette</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block25_l3_w5">
#           <Coords points="297,331 332,331 332,340 297,340"/>
#           <TextEquiv conf="0.4939999878">
#             <Unicode>Smoke</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block25_l3_w6">
#           <Coords points="341,331 355,331 355,339 341,339"/>
#           <TextEquiv conf="0.6499999762">
#             <Unicode>in</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block25_l3_w7">
#           <Coords points="362,331 390,331 390,341 362,341"/>
#           <TextEquiv conf="0.3950000107">
#             <Unicode>Dogs</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block26">
#       <Property key="language" value="en-US"/>
#       <Coords points="425,267 460,267 460,275 425,275"/>
#       <TextLine id="Page1_Block26_l1">
#         <Coords points="428,267 455,267 455,273 428,273"/>
#         <Word id="Page1_Block26_l1_w1">
#           <Coords points="428,267 455,267 455,273 428,273"/>
#           <TextEquiv conf="0.4350000024">
#             <Unicode>CODE</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block27">
#       <Property key="language" value="en-US"/>
#       <Coords points="60,384 221,384 221,396 60,396"/>
#       <TextLine id="Page1_Block27_l1">
#         <Coords points="64,385 216,385 216,394 64,394"/>
#         <Word id="Page1_Block27_l1_w1">
#           <Coords points="64,386 85,386 85,394 64,394"/>
#           <TextEquiv conf="0.3533333242">
#             <Unicode>For</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block27_l1_w2">
#           <Coords points="93,386 150,386 150,394 93,394"/>
#           <TextEquiv conf="0.4950000048">
#             <Unicode>Services</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block27_l1_w3">
#           <Coords points="158,385 216,385 216,394 158,394"/>
#           <TextEquiv conf="0.4799999893">
#             <Unicode>Rendered</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block28">
#       <Property key="language" value="en-US"/>
#       <Coords points="258,380 338,380 338,397 258,397"/>
#       <TextLine id="Page1_Block28_l1">
#         <Coords points="261,383 333,383 333,396 261,396"/>
#         <Word id="Page1_Block28_l1_w1">
#           <Coords points="261,385 294,385 294,396 261,396"/>
#           <TextEquiv conf="0.4679999948">
#             <Unicode>June,</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block28_l1_w2">
#           <Coords points="305,383 333,383 333,395 305,395"/>
#           <TextEquiv conf="0.6274999976">
#             <Unicode>1967</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block29">
#       <Property key="language" value="en-US"/>
#       <Coords points="59,439 209,439 209,456 59,456"/>
#       <TextLine id="Page1_Block29_l1">
#         <Coords points="63,439 207,439 207,451 63,451"/>
#         <Word id="Page1_Block29_l1_w1">
#           <Coords points="63,440 121,440 121,451 63,451"/>
#           <TextEquiv conf="0.5137500167">
#             <Unicode>Approved</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block29_l1_w2">
#           <Coords points="140,439 164,439 164,449 140,449"/>
#           <TextEquiv conf="0.3700000048">
#             <Unicode>////</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block29_l1_w3">
#           <Coords points="171,441 185,441 185,448 171,448"/>
#           <TextEquiv conf="0.1599999964">
#             <Unicode>Pt</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block29_l1_w4">
#           <Coords points="193,442 201,442 201,449 193,449"/>
#           <TextEquiv conf="0.1400000006">
#             <Unicode>r</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block29_l1_w5">
#           <Coords points="202,443 207,443 207,449 202,449"/>
#           <TextEquiv conf="0.1299999952">
#             <Unicode>0</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <ImageRegion id="Page1_Block30">
#       <Property key="alto-polygon" value="144,408 394,408 394,450 209,450 209,439 144,439 144,408"/>
#       <Coords points="144,408 394,408 394,450 144,450"/>
#     </ImageRegion>
#     <TextRegion id="Page1_Block31">
#       <Property key="language" value="en-US"/>
#       <Coords points="295,499 355,499 355,530 295,530"/>
#       <TextLine id="Page1_Block31_l1">
#         <Coords points="300,500 350,500 350,522 300,522"/>
#         <Word id="Page1_Block31_l1_w1">
#           <Coords points="300,514 304,514 304,517 300,517"/>
#           <TextEquiv conf="1">
#             <Unicode>'</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block31_l1_w2">
#           <Coords points="314,500 350,500 350,522 314,522"/>
#           <TextEquiv conf="0.4300000072">
#             <Unicode>9*</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block32">
#       <Property key="language" value="en-US"/>
#       <Coords points="101,598 368,598 368,646 101,646"/>
#       <TextLine id="Page1_Block32_l1">
#         <Coords points="179,598 288,598 288,604 179,604"/>
#         <Word id="Page1_Block32_l1_w1">
#           <Coords points="179,598 202,598 202,603 179,603"/>
#           <TextEquiv conf="0.6524999738">
#             <Unicode>MAKE</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l1_w2">
#           <Coords points="207,598 233,598 233,603 207,603"/>
#           <TextEquiv conf="0.4679999948">
#             <Unicode>CHECK</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l1_w3">
#           <Coords points="237,598 272,598 272,603 237,603"/>
#           <TextEquiv conf="0.5442857146">
#             <Unicode>PAYABLE</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l1_w4">
#           <Coords points="276,598 288,598 288,604 276,604"/>
#           <TextEquiv conf="0.5366666913">
#             <Unicode>TO:</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#       <TextLine id="Page1_Block32_l2">
#         <Coords points="105,607 363,607 363,616 105,616"/>
#         <Word id="Page1_Block32_l2_w1">
#           <Coords points="105,607 155,607 155,616 105,616"/>
#           <TextEquiv conf="0.8737499714">
#             <Unicode>CASHIER,</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l2_w2">
#           <Coords points="160,607 202,607 202,615 160,615"/>
#           <TextEquiv conf="0.6271428466">
#             <Unicode>PACIFIC</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l2_w3">
#           <Coords points="207,607 276,607 276,615 207,615"/>
#           <TextEquiv conf="0.7366666794">
#             <Unicode>NORTHWEST</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l2_w4">
#           <Coords points="281,607 363,607 363,615 281,615"/>
#           <TextEquiv conf="0.7783333063">
#             <Unicode>LABORATORIES</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#       <TextLine id="Page1_Block32_l3">
#         <Coords points="214,618 254,618 254,624 214,624"/>
#         <Word id="Page1_Block32_l3_w1">
#           <Coords points="214,618 237,618 237,624 214,624"/>
#           <TextEquiv conf="0.3680000007">
#             <Unicode>REMIT</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l3_w2">
#           <Coords points="242,618 254,618 254,624 242,624"/>
#           <TextEquiv conf="0.5466666818">
#             <Unicode>TO;</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#       <TextLine id="Page1_Block32_l4">
#         <Coords points="105,627 363,627 363,636 105,636"/>
#         <Word id="Page1_Block32_l4_w1">
#           <Coords points="105,627 155,627 155,636 105,636"/>
#           <TextEquiv conf="0.8687499762">
#             <Unicode>CASHIER,</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l4_w2">
#           <Coords points="160,627 202,627 202,635 160,635"/>
#           <TextEquiv conf="0.5457142591">
#             <Unicode>PACIFIC</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l4_w3">
#           <Coords points="207,627 276,627 276,635 207,635"/>
#           <TextEquiv conf="0.8733333349">
#             <Unicode>NORTHWEST</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l4_w4">
#           <Coords points="281,627 363,627 363,635 281,635"/>
#           <TextEquiv conf="0.8008333445">
#             <Unicode>LABORATORIES</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#       <TextLine id="Page1_Block32_l5">
#         <Coords points="142,637 327,637 327,644 142,644"/>
#         <Word id="Page1_Block32_l5_w1">
#           <Coords points="142,637 149,637 149,644 142,644"/>
#           <TextEquiv conf="0.474999994">
#             <Unicode>P.</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l5_w2">
#           <Coords points="153,637 162,637 162,643 153,643"/>
#           <TextEquiv conf="0.5849999785">
#             <Unicode>O.</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l5_w3">
#           <Coords points="167,637 186,637 186,643 167,643"/>
#           <TextEquiv conf="0.6566666961">
#             <Unicode>BOX</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l5_w4">
#           <Coords points="190,637 209,637 209,644 190,644"/>
#           <TextEquiv conf="0.3824999928">
#             <Unicode>999,</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l5_w5">
#           <Coords points="214,637 261,637 261,644 214,644"/>
#           <TextEquiv conf="0.603333354">
#             <Unicode>RICHLAND,</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l5_w6">
#           <Coords points="266,637 295,637 295,643 266,643"/>
#           <TextEquiv conf="0.7879999876">
#             <Unicode>WASH.</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block32_l5_w7">
#           <Coords points="300,637 327,637 327,644 300,644"/>
#           <TextEquiv conf="0.4539999962">
#             <Unicode>99352</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block33">
#       <Property key="language" value="en-US"/>
#       <Coords points="503,267 557,267 557,275 503,275"/>
#       <TextLine id="Page1_Block33_l1">
#         <Coords points="506,267 552,267 552,273 506,273"/>
#         <Word id="Page1_Block33_l1_w1">
#           <Coords points="506,267 552,267 552,273 506,273"/>
#           <TextEquiv conf="0.4524999857">
#             <Unicode>QUANTITY</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block34">
#       <Property key="language" value="en-US"/>
#       <Coords points="504,508 547,508 547,554 504,554"/>
#       <TextLine id="Page1_Block34_l1">
#         <Coords points="507,512 533,512 533,535 507,535"/>
#         <Word id="Page1_Block34_l1_w1">
#           <Coords points="507,512 533,512 533,535 507,535"/>
#           <TextEquiv conf="0.1850000024">
#             <Unicode>rt</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block35">
#       <Property key="language" value="en-US"/>
#       <Coords points="590,267 626,267 626,275 590,275"/>
#       <TextLine id="Page1_Block35_l1">
#         <Coords points="594,268 621,268 621,273 594,273"/>
#         <Word id="Page1_Block35_l1_w1">
#           <Coords points="594,268 621,268 621,273 594,273"/>
#           <TextEquiv conf="0.5360000134">
#             <Unicode>PRICK</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block36">
#       <Property key="language" value="en-US"/>
#       <Coords points="673,267 723,267 723,275 673,275"/>
#       <TextLine id="Page1_Block36_l1">
#         <Coords points="677,268 718,268 718,273 677,273"/>
#         <Word id="Page1_Block36_l1_w1">
#           <Coords points="677,268 718,268 718,273 677,273"/>
#           <TextEquiv conf="0.5383333564">
#             <Unicode>AMOUNT</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block37">
#       <Property key="language" value="en-US"/>
#       <Coords points="664,379 737,379 737,396 664,396"/>
#       <TextLine id="Page1_Block37_l1">
#         <Coords points="667,382 732,382 732,394 667,394"/>
#         <Word id="Page1_Block37_l1_w1">
#           <Coords points="667,382 732,382 732,394 667,394"/>
#           <TextEquiv conf="0.3400000036">
#             <Unicode>$2,755-55</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block38">
#       <Property key="language" value="en-US"/>
#       <Coords points="225,662 579,662 579,674 225,674"/>
#       <TextLine id="Page1_Block38_l1">
#         <Coords points="228,663 574,663 574,672 228,672"/>
#         <Word id="Page1_Block38_l1_w1">
#           <Coords points="228,663 265,663 265,671 228,671"/>
#           <TextEquiv conf="0.7983333468">
#             <Unicode>PLEASE</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block38_l1_w2">
#           <Coords points="270,664 310,664 310,671 270,671"/>
#           <TextEquiv conf="0.7450000048">
#             <Unicode>RETURN</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block38_l1_w3">
#           <Coords points="316,664 339,664 339,671 316,671"/>
#           <TextEquiv conf="0.9233333468">
#             <Unicode>ONE</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block38_l1_w4">
#           <Coords points="345,664 373,664 373,672 345,672"/>
#           <TextEquiv conf="0.7850000262">
#             <Unicode>COPY</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block38_l1_w5">
#           <Coords points="378,664 392,664 392,672 378,672"/>
#           <TextEquiv conf="0.7149999738">
#             <Unicode>OF</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block38_l1_w6">
#           <Coords points="397,664 420,664 420,672 397,672"/>
#           <TextEquiv conf="0.6000000238">
#             <Unicode>THIS</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block38_l1_w7">
#           <Coords points="425,664 470,664 470,672 425,672"/>
#           <TextEquiv conf="0.6057142615">
#             <Unicode>INVOICE</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block38_l1_w8">
#           <Coords points="475,664 502,664 502,672 475,672"/>
#           <TextEquiv conf="0.6299999952">
#             <Unicode>WITH</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block38_l1_w9">
#           <Coords points="508,664 574,664 574,672 508,672"/>
#           <TextEquiv conf="0.8000000119">
#             <Unicode>REMITTANCE</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block39">
#       <Property key="language" value="en-US"/>
#       <Coords points="51,687 88,687 88,695 51,695"/>
#       <TextLine id="Page1_Block39_l1">
#         <Coords points="55,687 83,687 83,693 55,693"/>
#         <Word id="Page1_Block39_l1_w1">
#           <Coords points="55,687 83,687 83,693 55,693"/>
#           <TextEquiv conf="0.2800000012">
#             <Unicode>Q25420)</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block40">
#       <Property key="language" value="en-US"/>
#       <Coords points="417,881 707,881 707,902 417,902"/>
#       <TextLine id="Page1_Block40_l1">
#         <Coords points="418,881 705,881 705,901 418,901"/>
#         <Word id="Page1_Block40_l1_w1">
#           <Coords points="418,881 461,881 461,900 418,900"/>
#           <TextEquiv conf="0.3833333254">
#             <Unicode>CTR</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block40_l1_w2">
#           <Coords points="479,881 597,881 597,900 479,900"/>
#           <TextEquiv conf="0.4099999964">
#             <Unicode>SP-FILES</Unicode>
#           </TextEquiv>
#         </Word>
#         <Word id="Page1_Block40_l1_w3">
#           <Coords points="616,882 705,882 705,901 616,901"/>
#           <TextEquiv conf="0.5816666484">
#             <Unicode>002572</Unicode>
#           </TextEquiv>
#         </Word>
#       </TextLine>
#     </TextRegion>
#     <TextRegion id="Page1_Block41">
#       <Property key="ComposedBlock" value="Page1_Block42 Page1_Block43 Page1_Block44 Page1_Block45"/>
#       <Coords points="79,594 387,594 387,649 79,649"/>
#     </TextRegion>
#     <SeparatorRegion id="Page1_Block42">
#       <Coords points="80,594 387,594 387,597 80,597"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block43">
#       <Coords points="80,647 387,647 387,649 80,649"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block44">
#       <Coords points="79,595 81,595 81,648 79,648"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block45">
#       <Coords points="385,595 387,595 387,649 385,649"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block46">
#       <Coords points="516,52 562,52 562,55 516,55"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block47">
#       <Coords points="262,57 317,57 317,61 262,61"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block48">
#       <Coords points="296,85 555,85 555,89 296,89"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block49">
#       <Coords points="57,102 483,102 483,105 57,105"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block50">
#       <Coords points="486,103 608,103 608,107 486,107"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block51">
#       <Coords points="618,103 750,103 750,106 618,106"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block52">
#       <Coords points="58,129 751,129 751,132 58,132"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block53">
#       <Coords points="58,155 750,155 750,159 58,159"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block54">
#       <Coords points="57,182 750,182 750,185 57,185"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block55">
#       <Coords points="58,209 627,209 627,214 58,214"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block56">
#       <Coords points="627,210 750,210 750,212 627,212"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block57">
#       <Coords points="57,235 543,235 543,239 57,239"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block58">
#       <Coords points="582,237 749,237 749,240 582,240"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block59">
#       <Coords points="57,262 749,262 749,266 57,266"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block60">
#       <Coords points="59,275 588,275 588,280 59,280"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block61">
#       <Coords points="588,277 749,277 749,279 588,279"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block62">
#       <Coords points="62,302 174,302 174,305 62,305"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block63">
#       <Coords points="289,440 351,440 351,444 289,444"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block64">
#       <Coords points="215,446 353,446 353,452 215,452"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block65">
#       <Coords points="128,448 215,448 215,454 128,454"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block66">
#       <Coords points="152,701 312,701 312,706 152,706"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block67">
#       <Coords points="395,263 399,263 399,349 395,349"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block68">
#       <Coords points="395,349 397,349 397,648 395,648"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block69">
#       <Coords points="474,103 478,103 478,183 474,183"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block70">
#       <Coords points="474,185 476,185 476,238 474,238"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block71">
#       <Coords points="486,265 489,265 489,649 486,649"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block72">
#       <Coords points="569,264 573,264 573,649 569,649"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block73">
#       <Coords points="642,279 645,279 645,649 642,649"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block74">
#       <Coords points="644,239 645,239 645,277 644,277"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block75">
#       <Coords points="164,238 166,238 166,264 164,264"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block76">
#       <Coords points="352,236 355,236 355,261 352,261"/>
#     </SeparatorRegion>
#     <SeparatorRegion id="Page1_Block77">
#       <Coords points="535,237 538,237 538,263 535,263"/>
#     </SeparatorRegion>
#   </Page>
# </PcGts>

# %% [markdown]
# # Observations:
#
# ```
# # The structure of xml(for our interest) is:
# # <TextRegion>
# #     <TextLine>
# #         <Word>
# #             <Unicode> Text </Unicode>
# #         </Word>
# #     </TextLine>
# # </TextRegion>
# ```
#
# **Information in a particular text region (< TextRegion >) is a block of information which is of the same type like address or description. But this block of informaiton may be divided into different lines (< TextLine >).**
#
# While reading we need to club information according to text line and text region to make it more reasonable so that sequential property of the text data could be preserved. Opposed to this a normal final_all text in xml would give non sequential data where sequential property of the data will be lost. Information from XML can be extracted row wise, block wise or all the text altogether. Row wise text is smaller in size and contains less sequential information so it will be better to use if for regex comparison. While whole text together or block wise information is expected to be in more sequential manner and thus more suitable for unsupervised learning methods (not supervise because of no labeled data).
#
# NOTE: From xml we are currently not taking the confidence into account, for a better model confidence threshold should be decided/optimized and used.
#
# Parsing the XML file using element tree:

# %%
from lxml import etree, objectify

parser = etree.XMLParser(remove_blank_text=True)
tree = etree.parse(os.path.join(dirname,file_list[0]))
root = tree.getroot()

#This file contains xml name space which come attached with each tag, 
#xmlns makes it difficult for a reader to focus on desired tag, so we remove the namespaces
for elem in root.getiterator():
    if not hasattr(elem.tag, 'find'): continue  
    i = elem.tag.find('}')
    if i >= 0:
        elem.tag = elem.tag[i+1:]
objectify.deannotate(root, cleanup_namespaces=True)

# %%
#all the tag in xml are added to tag_list 
tag_list = []
for element in root.iter():
    tag_list = element.tag

# %%
# check the output if its in the same order as we need it
for element in root.iter('Word'):
    print('block and line info = ' + str(element.attrib))
    for child in element:
        #print(child.tag)
        if child.tag == 'TextEquiv':
            print('for text confidence score =' + str(child.attrib))
            for grandchild in child:
                if grandchild.tag == 'Unicode':
                    print('text = '+str(grandchild.text))
# Out:
# block and line info = {'id': 'Page1_Block1_l1_w1'}
# for text confidence score ={'conf': '0.473333329'}
# text = 8**
# block and line info = {'id': 'Page1_Block1_l1_w2'}
# for text confidence score ={'conf': '0.6075000167'}
# text = ICO^
# block and line info = {'id': 'Page1_Block2_l1_w1'}
# for text confidence score ={'conf': '0.150000006'}
# text = f
# block and line info = {'id': 'Page1_Block2_l1_w2'}
# for text confidence score ={'conf': '0.2599999905'}
# text = *
# block and line info = {'id': 'Page1_Block4_l1_w1'}
# for text confidence score ={'conf': '0.6342856884'}
# text = INVOICE
# block and line info = {'id': 'Page1_Block4_l1_w2'}
# for text confidence score ={'conf': '0.5433333516'}
# text = NO.
# block and line info = {'id': 'Page1_Block4_l2_w1'}
# for text confidence score ={'conf': '0.4099999964'}
# text = B-07025
# block and line info = {'id': 'Page1_Block5_l1_w1'}
# for text confidence score ={'conf': '0.337500006'}
# text = SOLO
# block and line info = {'id': 'Page1_Block5_l1_w2'}
# for text confidence score ={'conf': '0.3799999952'}
# text = TO
# block and line info = {'id': 'Page1_Block6_l1_w1'}
# for text confidence score ={'conf': '0.4066666663'}
# text = The
# block and line info = {'id': 'Page1_Block6_l1_w2'}
# for text confidence score ={'conf': '0.4728571475'}
# text = Council
# block and line info = {'id': 'Page1_Block6_l1_w3'}
# for text confidence score ={'conf': '0.3199999928'}
# text = for
# block and line info = {'id': 'Page1_Block6_l1_w4'}
# for text confidence score ={'conf': '0.4257142842'}
# text = Tobacco
# block and line info = {'id': 'Page1_Block6_l1_w5'}
# for text confidence score ={'conf': '0.4600000083'}
# text = Research
# block and line info = {'id': 'Page1_Block7_l1_w1'}
# for text confidence score ={'conf': '0.2700000107'}
# text = DATE
# block and line info = {'id': 'Page1_Block8_l1_w1'}
# for text confidence score ={'conf': '0.4842857122'}
# text = 7-13-67
# block and line info = {'id': 'Page1_Block9_l1_w1'}
# for text confidence score ={'conf': '0.1933333278'}
# text = crcoiV
# block and line info = {'id': 'Page1_Block9_l1_w2'}
# for text confidence score ={'conf': '0.25'}
# text = do6c
# block and line info = {'id': 'Page1_Block9_l2_w1'}
# for text confidence score ={'conf': '0.5224999785'}
# text = 033B
# block and line info = {'id': 'Page1_Block11_l1_w1'}
# for text confidence score ={'conf': '0.2771428525'}
# text = XEBXiss
# block and line info = {'id': 'Page1_Block11_l1_w2'}
# for text confidence score ={'conf': '0.1599999964'}
# text = :
# block and line info = {'id': 'Page1_Block11_l1_w3'}
# for text confidence score ={'conf': '0.1550000012'}
# text = rr
# block and line info = {'id': 'Page1_Block11_l2_w1'}
# for text confidence score ={'conf': '0.3366666734'}
# text = 633
# block and line info = {'id': 'Page1_Block11_l2_w2'}
# for text confidence score ={'conf': '0.3359999955'}
# text = Third
# block and line info = {'id': 'Page1_Block11_l2_w3'}
# for text confidence score ={'conf': '0.6833333373'}
# text = Avenue
# block and line info = {'id': 'Page1_Block12_l1_w1'}
# for text confidence score ={'conf': '0.6933333278'}
# text = Net
# block and line info = {'id': 'Page1_Block12_l1_w2'}
# for text confidence score ={'conf': '0.4149999917'}
# text = 30
# block and line info = {'id': 'Page1_Block12_l1_w3'}
# for text confidence score ={'conf': '0.5174999833'}
# text = Days
# block and line info = {'id': 'Page1_Block13_l1_w1'}
# for text confidence score ={'conf': '0.4766666591'}
# text = New
# block and line info = {'id': 'Page1_Block13_l1_w2'}
# for text confidence score ={'conf': '0.400000006'}
# text = York,
# block and line info = {'id': 'Page1_Block13_l1_w3'}
# for text confidence score ={'conf': '0.3566666543'}
# text = New
# block and line info = {'id': 'Page1_Block13_l1_w4'}
# for text confidence score ={'conf': '0.5325000286'}
# text = York
# block and line info = {'id': 'Page1_Block13_l1_w5'}
# for text confidence score ={'conf': '0.7620000243'}
# text = 10017
# block and line info = {'id': 'Page1_Block14_l1_w1'}
# for text confidence score ={'conf': '0.5350000262'}
# text = Attention:
# block and line info = {'id': 'Page1_Block14_l1_w2'}
# for text confidence score ={'conf': '0.6266666651'}
# text = Dr.
# block and line info = {'id': 'Page1_Block14_l1_w3'}
# for text confidence score ={'conf': '0.625'}
# text = R.
# block and line info = {'id': 'Page1_Block14_l1_w4'}
# for text confidence score ={'conf': '0.4300000072'}
# text = C.
# block and line info = {'id': 'Page1_Block14_l1_w5'}
# for text confidence score ={'conf': '0.6057142615'}
# text = Hockett
# block and line info = {'id': 'Page1_Block15_l1_w1'}
# for text confidence score ={'conf': '0.5672727227'}
# text = DESTINATION
# block and line info = {'id': 'Page1_Block16_l1_w1'}
# for text confidence score ={'conf': '0.6240000129'}
# text = CUSTOMER’S
# block and line info = {'id': 'Page1_Block16_l1_w2'}
# for text confidence score ={'conf': '0.4140000045'}
# text = ORDER
# block and line info = {'id': 'Page1_Block16_l1_w3'}
# for text confidence score ={'conf': '0.3766666651'}
# text = NO.
# block and line info = {'id': 'Page1_Block16_l1_w4'}
# for text confidence score ={'conf': '0.400000006'}
# text = B/L
# block and line info = {'id': 'Page1_Block16_l1_w5'}
# for text confidence score ={'conf': '0.3966666758'}
# text = NO.
# block and line info = {'id': 'Page1_Block16_l2_w1'}
# for text confidence score ={'conf': '0.5174999833'}
# text = BNPI
# block and line info = {'id': 'Page1_Block16_l2_w2'}
# for text confidence score ={'conf': '0.7466666698'}
# text = -19
# block and line info = {'id': 'Page1_Block16_l2_w3'}
# for text confidence score ={'conf': '0.3485714197'}
# text = 5-Subst
# block and line info = {'id': 'Page1_Block16_l2_w4'}
# for text confidence score ={'conf': '0.9300000072'}
# text = i
# block and line info = {'id': 'Page1_Block16_l2_w5'}
# for text confidence score ={'conf': '0.5500000119'}
# text = tut
# block and line info = {'id': 'Page1_Block16_l2_w6'}
# for text confidence score ={'conf': '0.1800000072'}
# text = e
# block and line info = {'id': 'Page1_Block17_l1_w1'}
# for text confidence score ={'conf': '1'}
# text = |
# block and line info = {'id': 'Page1_Block17_l1_w2'}
# for text confidence score ={'conf': '0.1366666704'}
# text = O/L
# block and line info = {'id': 'Page1_Block17_l1_w3'}
# for text confidence score ={'conf': '0.5350000262'}
# text = WOT.
# block and line info = {'id': 'Page1_Block18_l1_w1'}
# for text confidence score ={'conf': '0.448333323'}
# text = F.O.B.
# block and line info = {'id': 'Page1_Block19_l1_w1'}
# for text confidence score ={'conf': '0.4699999988'}
# text = CAR
# block and line info = {'id': 'Page1_Block19_l1_w2'}
# for text confidence score ={'conf': '0.4583333433'}
# text = INTLS.
# block and line info = {'id': 'Page1_Block19_l1_w3'}
# for text confidence score ={'conf': '0.5699999928'}
# text = ft
# block and line info = {'id': 'Page1_Block19_l1_w4'}
# for text confidence score ={'conf': '0.2666666806'}
# text = NO.
# block and line info = {'id': 'Page1_Block20_l1_w1'}
# for text confidence score ={'conf': '0.2028571367'}
# text = SHIPPIP
# block and line info = {'id': 'Page1_Block21_l1_w1'}
# for text confidence score ={'conf': '0.2649999857'}
# text = IO
# block and line info = {'id': 'Page1_Block21_l1_w2'}
# for text confidence score ={'conf': '0.5299999714'}
# text = POINT
# block and line info = {'id': 'Page1_Block22_l1_w1'}
# for text confidence score ={'conf': '0.003333333414'}
# text = PNL
# block and line info = {'id': 'Page1_Block22_l1_w2'}
# for text confidence score ={'conf': '0.6019999981'}
# text = ORDER
# block and line info = {'id': 'Page1_Block22_l1_w3'}
# for text confidence score ={'conf': '0.5'}
# text = NO.
# block and line info = {'id': 'Page1_Block23_l1_w1'}
# for text confidence score ={'conf': '0.4724999964'}
# text = DATE
# block and line info = {'id': 'Page1_Block23_l1_w2'}
# for text confidence score ={'conf': '0.5028571486'}
# text = SHIPPED
# block and line info = {'id': 'Page1_Block24_l1_w1'}
# for text confidence score ={'conf': '0.4211111069'}
# text = COMMODITY
# block and line info = {'id': 'Page1_Block25_l1_w1'}
# for text confidence score ={'conf': '0.5942857265'}
# text = Project
# block and line info = {'id': 'Page1_Block25_l1_w2'}
# for text confidence score ={'conf': '0.3799999952'}
# text = Y
# block and line info = {'id': 'Page1_Block25_l1_w3'}
# for text confidence score ={'conf': '0.5133333206'}
# text = 1^0153
# block and line info = {'id': 'Page1_Block25_l2_w1'}
# for text confidence score ={'conf': '0.53125'}
# text = Research
# block and line info = {'id': 'Page1_Block25_l2_w2'}
# for text confidence score ={'conf': '0.6299999952'}
# text = on
# block and line info = {'id': 'Page1_Block25_l2_w3'}
# for text confidence score ={'conf': '0.5571428537'}
# text = Methods
# block and line info = {'id': 'Page1_Block25_l2_w4'}
# for text confidence score ={'conf': '0.3899999857'}
# text = of
# block and line info = {'id': 'Page1_Block25_l2_w5'}
# for text confidence score ={'conf': '0.6277777553'}
# text = Measuring
# block and line info = {'id': 'Page1_Block25_l2_w6'}
# for text confidence score ={'conf': '0.400000006'}
# text = the
# block and line info = {'id': 'Page1_Block25_l3_w1'}
# for text confidence score ={'conf': '0.4830000103'}
# text = Deposition
# block and line info = {'id': 'Page1_Block25_l3_w2'}
# for text confidence score ={'conf': '0.6600000262'}
# text = of
# block and line info = {'id': 'Page1_Block25_l3_w3'}
# for text confidence score ={'conf': '0.495714277'}
# text = Inhaled
# block and line info = {'id': 'Page1_Block25_l3_w4'}
# for text confidence score ={'conf': '0.6355555654'}
# text = Cigarette
# block and line info = {'id': 'Page1_Block25_l3_w5'}
# for text confidence score ={'conf': '0.4939999878'}
# text = Smoke
# block and line info = {'id': 'Page1_Block25_l3_w6'}
# for text confidence score ={'conf': '0.6499999762'}
# text = in
# block and line info = {'id': 'Page1_Block25_l3_w7'}
# for text confidence score ={'conf': '0.3950000107'}
# text = Dogs
# block and line info = {'id': 'Page1_Block26_l1_w1'}
# for text confidence score ={'conf': '0.4350000024'}
# text = CODE
# block and line info = {'id': 'Page1_Block27_l1_w1'}
# for text confidence score ={'conf': '0.3533333242'}
# text = For
# block and line info = {'id': 'Page1_Block27_l1_w2'}
# for text confidence score ={'conf': '0.4950000048'}
# text = Services
# block and line info = {'id': 'Page1_Block27_l1_w3'}
# for text confidence score ={'conf': '0.4799999893'}
# text = Rendered
# block and line info = {'id': 'Page1_Block28_l1_w1'}
# for text confidence score ={'conf': '0.4679999948'}
# text = June,
# block and line info = {'id': 'Page1_Block28_l1_w2'}
# for text confidence score ={'conf': '0.6274999976'}
# text = 1967
# block and line info = {'id': 'Page1_Block29_l1_w1'}
# for text confidence score ={'conf': '0.5137500167'}
# text = Approved
# block and line info = {'id': 'Page1_Block29_l1_w2'}
# for text confidence score ={'conf': '0.3700000048'}
# text = ////
# block and line info = {'id': 'Page1_Block29_l1_w3'}
# for text confidence score ={'conf': '0.1599999964'}
# text = Pt
# block and line info = {'id': 'Page1_Block29_l1_w4'}
# for text confidence score ={'conf': '0.1400000006'}
# text = r
# block and line info = {'id': 'Page1_Block29_l1_w5'}
# for text confidence score ={'conf': '0.1299999952'}
# text = 0
# block and line info = {'id': 'Page1_Block31_l1_w1'}
# for text confidence score ={'conf': '1'}
# text = '
# block and line info = {'id': 'Page1_Block31_l1_w2'}
# for text confidence score ={'conf': '0.4300000072'}
# text = 9*
# block and line info = {'id': 'Page1_Block32_l1_w1'}
# for text confidence score ={'conf': '0.6524999738'}
# text = MAKE
# block and line info = {'id': 'Page1_Block32_l1_w2'}
# for text confidence score ={'conf': '0.4679999948'}
# text = CHECK
# block and line info = {'id': 'Page1_Block32_l1_w3'}
# for text confidence score ={'conf': '0.5442857146'}
# text = PAYABLE
# block and line info = {'id': 'Page1_Block32_l1_w4'}
# for text confidence score ={'conf': '0.5366666913'}
# text = TO:
# block and line info = {'id': 'Page1_Block32_l2_w1'}
# for text confidence score ={'conf': '0.8737499714'}
# text = CASHIER,
# block and line info = {'id': 'Page1_Block32_l2_w2'}
# for text confidence score ={'conf': '0.6271428466'}
# text = PACIFIC
# block and line info = {'id': 'Page1_Block32_l2_w3'}
# for text confidence score ={'conf': '0.7366666794'}
# text = NORTHWEST
# block and line info = {'id': 'Page1_Block32_l2_w4'}
# for text confidence score ={'conf': '0.7783333063'}
# text = LABORATORIES
# block and line info = {'id': 'Page1_Block32_l3_w1'}
# for text confidence score ={'conf': '0.3680000007'}
# text = REMIT
# block and line info = {'id': 'Page1_Block32_l3_w2'}
# for text confidence score ={'conf': '0.5466666818'}
# text = TO;
# block and line info = {'id': 'Page1_Block32_l4_w1'}
# for text confidence score ={'conf': '0.8687499762'}
# text = CASHIER,
# block and line info = {'id': 'Page1_Block32_l4_w2'}
# for text confidence score ={'conf': '0.5457142591'}
# text = PACIFIC
# block and line info = {'id': 'Page1_Block32_l4_w3'}
# for text confidence score ={'conf': '0.8733333349'}
# text = NORTHWEST
# block and line info = {'id': 'Page1_Block32_l4_w4'}
# for text confidence score ={'conf': '0.8008333445'}
# text = LABORATORIES
# block and line info = {'id': 'Page1_Block32_l5_w1'}
# for text confidence score ={'conf': '0.474999994'}
# text = P.
# block and line info = {'id': 'Page1_Block32_l5_w2'}
# for text confidence score ={'conf': '0.5849999785'}
# text = O.
# block and line info = {'id': 'Page1_Block32_l5_w3'}
# for text confidence score ={'conf': '0.6566666961'}
# text = BOX
# block and line info = {'id': 'Page1_Block32_l5_w4'}
# for text confidence score ={'conf': '0.3824999928'}
# text = 999,
# block and line info = {'id': 'Page1_Block32_l5_w5'}
# for text confidence score ={'conf': '0.603333354'}
# text = RICHLAND,
# block and line info = {'id': 'Page1_Block32_l5_w6'}
# for text confidence score ={'conf': '0.7879999876'}
# text = WASH.
# block and line info = {'id': 'Page1_Block32_l5_w7'}
# for text confidence score ={'conf': '0.4539999962'}
# text = 99352
# block and line info = {'id': 'Page1_Block33_l1_w1'}
# for text confidence score ={'conf': '0.4524999857'}
# text = QUANTITY
# block and line info = {'id': 'Page1_Block34_l1_w1'}
# for text confidence score ={'conf': '0.1850000024'}
# text = rt
# block and line info = {'id': 'Page1_Block35_l1_w1'}
# for text confidence score ={'conf': '0.5360000134'}
# text = PRICK
# block and line info = {'id': 'Page1_Block36_l1_w1'}
# for text confidence score ={'conf': '0.5383333564'}
# text = AMOUNT
# block and line info = {'id': 'Page1_Block37_l1_w1'}
# for text confidence score ={'conf': '0.3400000036'}
# text = $2,755-55
# block and line info = {'id': 'Page1_Block38_l1_w1'}
# for text confidence score ={'conf': '0.7983333468'}
# text = PLEASE
# block and line info = {'id': 'Page1_Block38_l1_w2'}
# for text confidence score ={'conf': '0.7450000048'}
# text = RETURN
# block and line info = {'id': 'Page1_Block38_l1_w3'}
# for text confidence score ={'conf': '0.9233333468'}
# text = ONE
# block and line info = {'id': 'Page1_Block38_l1_w4'}
# for text confidence score ={'conf': '0.7850000262'}
# text = COPY
# block and line info = {'id': 'Page1_Block38_l1_w5'}
# for text confidence score ={'conf': '0.7149999738'}
# text = OF
# block and line info = {'id': 'Page1_Block38_l1_w6'}
# for text confidence score ={'conf': '0.6000000238'}
# text = THIS
# block and line info = {'id': 'Page1_Block38_l1_w7'}
# for text confidence score ={'conf': '0.6057142615'}
# text = INVOICE
# block and line info = {'id': 'Page1_Block38_l1_w8'}
# for text confidence score ={'conf': '0.6299999952'}
# text = WITH
# block and line info = {'id': 'Page1_Block38_l1_w9'}
# for text confidence score ={'conf': '0.8000000119'}
# text = REMITTANCE
# block and line info = {'id': 'Page1_Block39_l1_w1'}
# for text confidence score ={'conf': '0.2800000012'}
# text = Q25420)
# block and line info = {'id': 'Page1_Block40_l1_w1'}
# for text confidence score ={'conf': '0.3833333254'}
# text = CTR
# block and line info = {'id': 'Page1_Block40_l1_w2'}
# for text confidence score ={'conf': '0.4099999964'}
# text = SP-FILES
# block and line info = {'id': 'Page1_Block40_l1_w3'}
# for text confidence score ={'conf': '0.5816666484'}
# text = 002572

# %%
# getting the information in the format in which we need it:
import re
prev_block_Page = ''
prev_block_Block = ''
prev_block_Line = ''
prev_block_Word = ''
sentence = ''
sentence2 = ''
sentence3 = ''
block = []
line = []
for element in root.iter('Unicode'):
    same_page = same_block = same_line = next_word = False
    parent_node = next(element.iterancestors('Word'))
    block_list = parent_node.attrib['id'].split('_')
    if(prev_block_Page == block_list[0] or prev_block_Page == ''):
        same_page = True
    if(prev_block_Block == block_list[1] or prev_block_Block == ''):
        same_block = True        
    if(prev_block_Line == block_list[2] or prev_block_Line == ''):
        same_line = True
    if(prev_block_Word == int(block_list[3][1:])-1 or prev_block_Word == ''):
        next_word = True
                    
    #only same line present in one sentnece:
    #Here we check if the sentence contains the keywords which we are looking for like 'Date'
    if same_line and same_block:
        sentence3 = sentence3 + re.sub("[^0-9a-zA-Z:,]+", ' ',element.text) + ' ' 
    else:
        line.append(sentence3)
        sentence3 = ''
        sentence3 = sentence3 + re.sub("[^0-9a-zA-Z:,]+", ' ',element.text)+ ' '
    
    #same block in one line:
    if same_block:
        sentence = sentence + re.sub("[^0-9a-zA-Z:,]+", ' ',element.text) + ' '
    else:
        block.append(sentence)
        sentence = ''
        sentence = sentence + re.sub("[^0-9a-zA-Z:,]+", ' ',element.text)+ ' '  
      
    #all text in same line:
    sentence2 = sentence2 + re.sub("[^0-9a-zA-Z:,]+", ' ',element.text) + ' '
        
    prev_block_Page = block_list[0]
    prev_block_Block = block_list[1]
    prev_block_Line = block_list[2]
    prev_block_Word = int(block_list[3][1:])
print(line)
print(block)    
print(sentence2)
# Out:
# ['8  ICO  ', 'f   ', 'INVOICE NO  ', 'B 07025 ', 'SOLO TO ', 'The Council for Tobacco Research ', 'DATE ', '7 13 67 ', 'crcoiV do6c ', '033B ', 'XEBXiss : rr ', '633 Third Avenue ', 'Net 30 Days ', 'New York, New York 10017 ', 'Attention: Dr  R  C  Hockett ', 'DESTINATION ', 'CUSTOMER S ORDER NO  B L NO  ', 'BNPI  19 5 Subst i tut e ', '  O L WOT  ', 'F O B  ', 'CAR INTLS  ft NO  ', 'SHIPPIP ', 'IO POINT ', 'PNL ORDER NO  ', 'DATE SHIPPED ', 'COMMODITY ', 'Project Y 1 0153 ', 'Research on Methods of Measuring the ', 'Deposition of Inhaled Cigarette Smoke in Dogs ', 'CODE ', 'For Services Rendered ', 'June, 1967 ', 'Approved   Pt r 0 ', '  9  ', 'MAKE CHECK PAYABLE TO: ', 'CASHIER, PACIFIC NORTHWEST LABORATORIES ', 'REMIT TO  ', 'CASHIER, PACIFIC NORTHWEST LABORATORIES ', 'P  O  BOX 999, RICHLAND, WASH  99352 ', 'QUANTITY ', 'rt ', 'PRICK ', 'AMOUNT ', ' 2,755 55 ', 'PLEASE RETURN ONE COPY OF THIS INVOICE WITH REMITTANCE ', 'Q25420  ']
# ['8  ICO  ', 'f   ', 'INVOICE NO  B 07025 ', 'SOLO TO ', 'The Council for Tobacco Research ', 'DATE ', '7 13 67 ', 'crcoiV do6c 033B ', 'XEBXiss : rr 633 Third Avenue ', 'Net 30 Days ', 'New York, New York 10017 ', 'Attention: Dr  R  C  Hockett ', 'DESTINATION ', 'CUSTOMER S ORDER NO  B L NO  BNPI  19 5 Subst i tut e ', '  O L WOT  ', 'F O B  ', 'CAR INTLS  ft NO  ', 'SHIPPIP ', 'IO POINT ', 'PNL ORDER NO  ', 'DATE SHIPPED ', 'COMMODITY ', 'Project Y 1 0153 Research on Methods of Measuring the Deposition of Inhaled Cigarette Smoke in Dogs ', 'CODE ', 'For Services Rendered ', 'June, 1967 ', 'Approved   Pt r 0 ', '  9  ', 'MAKE CHECK PAYABLE TO: CASHIER, PACIFIC NORTHWEST LABORATORIES REMIT TO  CASHIER, PACIFIC NORTHWEST LABORATORIES P  O  BOX 999, RICHLAND, WASH  99352 ', 'QUANTITY ', 'rt ', 'PRICK ', 'AMOUNT ', ' 2,755 55 ', 'PLEASE RETURN ONE COPY OF THIS INVOICE WITH REMITTANCE ', 'Q25420  ']
# 8  ICO  f   INVOICE NO  B 07025 SOLO TO The Council for Tobacco Research DATE 7 13 67 crcoiV do6c 033B XEBXiss : rr 633 Third Avenue Net 30 Days New York, New York 10017 Attention: Dr  R  C  Hockett DESTINATION CUSTOMER S ORDER NO  B L NO  BNPI  19 5 Subst i tut e   O L WOT  F O B  CAR INTLS  ft NO  SHIPPIP IO POINT PNL ORDER NO  DATE SHIPPED COMMODITY Project Y 1 0153 Research on Methods of Measuring the Deposition of Inhaled Cigarette Smoke in Dogs CODE For Services Rendered June, 1967 Approved   Pt r 0   9  MAKE CHECK PAYABLE TO: CASHIER, PACIFIC NORTHWEST LABORATORIES REMIT TO  CASHIER, PACIFIC NORTHWEST LABORATORIES P  O  BOX 999, RICHLAND, WASH  99352 QUANTITY rt PRICK AMOUNT  2,755 55 PLEASE RETURN ONE COPY OF THIS INVOICE WITH REMITTANCE Q25420  CTR SP FILES 002572

# %%
###########################################################################################
###########                                                                     ###########
########### This is the summary of complete process, looping over all the files ###########                      
###########                                                                     ###########
###########################################################################################
#Do the whole process on the list of all the files:
#Reading the file saving the contents in data and proceeding 

filename = 'beautiful_data.txt'
write_txt_to_file = open(filename,'a')
write_txt_to_file.write(sentence2)
write_txt_to_file.close()

# %%
import csv
field = ['TEXT']
row = sentence
filename = 'beautiful_data.csv'
with open(filename,'a',newline='') as csvfile:
    csvwriter = csv.writer(csvfile)#creates an object for writing in csv files
    csvwriter.writerow(sentence)

# %%
###########################################################################################
###########                                                                     ###########
########### This is the summary of complete process, looping over all the files ###########                      
###########                                                                     ###########
###########################################################################################
#Do the whole process on the list of all the files:
#Reading the file saving the contents in data and proceeding 

txt_filename = 'beautiful_data_summary.txt'
for xml_file in file_list:
    parser = None
    root = None
    tree = None
    new_sentence = ''
    parser = etree.XMLParser(remove_blank_text=True)
    xml_file_path = os.path.join(dirname,xml_file)
    tree = etree.parse(xml_file_path)
    root = tree.getroot()
    #remove the namespaces
    for elem in root.getiterator():
        if not hasattr(elem.tag, 'find'): continue  
        i = elem.tag.find('}')
        if i >= 0:
            elem.tag = elem.tag[i+1:]
    objectify.deannotate(root, cleanup_namespaces=True)
    
    for element in root.iter('Unicode'):
        new_sentence = new_sentence + re.sub("[^0-9a-zA-Z:,]+", ' ',element.text) + ' '
    #print('new_sentence = '+new_sentence)    
    #writing the new_sentence in the file 
    wrtie_txt_to_file = None
    write_txt_to_file = open(txt_filename,'a')
    write_txt_to_file.write(new_sentence)
    write_txt_to_file.write('\n')
    write_txt_to_file.close()

# %%
import pandas as pd
pd.set_option('display.max_colwidth',3000)
df = pd.read_csv('./beautiful_data_summary.txt',delimiter='/n',header=None)
df.head(7)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         8  ICO  f   INVOICE NO  B 07025 SOLO TO The Council for Tobacco Research DATE 7 13 67 crcoiV do6c 033B XEBXiss : rr 633 Third Avenue Net 30 Days New York, New York 10017 Attention: Dr  R  C  Hockett DESTINATION CUSTOMER S ORDER NO  B L NO  BNPI  19 5 Subst i tut e   O L WOT  F O B  CAR INTLS  ft NO  SHIPPIP IO POINT PNL ORDER NO  DATE SHIPPED COMMODITY Project Y 1 0153 Research on Methods of Measuring the Deposition of Inhaled Cigarette Smoke in Dogs CODE For Services Rendered June, 1967 Approved   Pt r 0   9  MAKE CHECK PAYABLE TO: CASHIER, PACIFIC NORTHWEST LABORATORIES REMIT TO  CASHIER, PACIFIC NORTHWEST LABORATORIES P  O  BOX 999, RICHLAND, WASH  99352 QUANTITY rt PRICK AMOUNT  2,755 55 PLEASE RETURN ONE COPY OF THIS INVOICE WITH REMITTANCE Q25420  CTR SP FILES 002572
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Philip Morris USA BUSINESS fVOUCW herT PHILIP MORRIS USA VOUCHER DATE: Oct  14  1996 PLEASE READ INSTRUCTIONS ON PAGE 2  PAYEE: CEHHT  Inc  SPECIAL INSTRUCTIONS: PLEASE SEND THIS 6001 Mohtfose Boid  Suite 4o   2a  XI V  CHECK TO MARGARET OPOCENSKY  R D A 2  ROCk ile, lD20852 FOR TRANSMITTAL  COST CENTER EXPLANATION OF PAYMENT TO BE CHARGED S AMOUNT Env  Tob  Smoke Literature Database for July 1 31,1996 2R1  5,000 00 Env  Tob  Smoke Literature Database for Auq  1 31,1996 2R1 SI 5 000 00 Total S20 000 00 1 PREPARED BY: Margaret Opocensky CHECK DATE DUE:   Oct 18, 19096 LOCATION: R D   A 2 Extension: 3882 APPROVED: M   R  A  Carchman FOR ACCOUNTING USE ONLY VENDOR: INVOICE NO : gl account amount  Q  111 V vlvL 1 ivii INVOICE AMOUNT: INVOICE DATE: ACTION: i  1 2  1 3  1 4  1 P O NBR  Q : 5  1 DUE DATE  Q : CHECK DESCRIPTION  1 : 6  1 7  1 a 1 9  1 10  1 ACCTG  AUDIT: ii  1 12 1 13 1 ACCTG  APPROVAL: 14  1 DATA ENTRY: 15 1 FORWARD THIS COPY TO: CASH DISBURSEMENTS   FINANCE CENTER DOC CODE: V0120 2063610122
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               the commercial 211 EAST 4 3RD STREET   NEW YORK  N Y  TO: Mr  Neil Holbert Philip Morris, USA 100 Park Avenue   New York, New York 10017 Date Invoice   Our Job   Ycur P O    : 10017     945 9040 2 28 78 2758 3050 INVOICE TITLE: Cigarette Tracking   1978 FEE:    111,300 00   5  BALANCE DUE: First Partial Payment  37,100 00 P tate no:  all cutmcnrjirss sna ISM cotit art stated fct :ix monr i  a I tit zcrroie: cn cf tr t jfwCV era tr en discord li zr leze i written rscutit tr a: tr sy zt sene to you  : received  MARKETING  ECONOMIC AND MOTIVATION RESEARCH 2042525639
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          86 MAPLE AVE  NEW CITY, N Y, 10956 5036 914 634 1331 800 767 7967  AX:914 634 9618 Mr  Andrew Pasheluk Lorillard Tobacco Co 714 Green Valley Rd Box 10529 Greensboro NC 27408 7018 received jul i   MP1D INVOICE  : 99065516 INV  DATE: 07 01 99 ACCOUNT   5516 BILLING PERIOD: 06 01 99 to 06 30 99 TERMS:   PCS DESCRIPTION PIECE RATE 1 55 OZ RATE 0 00 TOTAL 22 1 OZ  MAIL PIECES 34 10 34 10 80 2 OZ  MAIL PIECES 124 00 0 00 124 00 102 TOTAL 158 10 0 00 158 10  lUAL SERVICE CHARGE 200 00  TOTALZOSSUBBS  CHARGES SUMMARY OF ACCOUNT PAST DUE PAYMENTS CREDITS CURRENT BILLING FINANCE CHARGE 6 20  6 20 358 10 0 00  358 10 PAYMENT DUE UPON REC E INCLUDE YOUR ACCOUNT   5516 FOR PROPER CREDIT  CO Os Os CSJ O  J o PAST DUE BALANCES ARE SUBJECT TO A 1 5  MONTHLY FINANCE CHARGE
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    MANAGEMENT SCIENCE ASSOCIATES, INC  6565 Penn Avenue at Fifth Pittsburgh, PA 15206 4490  4121 362 200C nr  TO: Mr  Odvc TenBarge PHILIP MORRIS, U S A  120 Park Avenue , flew York, NY 10017 INVOICE SEND REMITTANCE TO: Management Science Associates, In P O  Box 400155 W PiltsOuigh  Pennsylvania 15268 0155   PLEASE REFER tg OUR I WCHGEJiMI OR RETURN IHVOlCEXOPY WMEMR AMOUNTS NOT RECEIVED WITHIN 30 DAYS OF INVOICE DATE ARE SUBJECT TO 1 5  MONTHLY SERVICE CHARGE  18  PER ANNUM  INVOICE Nuue fT  9210153 iMvoict o rc October 26, 1992  l NT AUTHOR 2ATION NUMBER FEDERAL ID NO  25 1126415 : ItebmT V  NET 10 DA DESCRIPTION AMOUNT  ALES  , INFORMATION SVCS DATANET USAGE 0TH7O14 September 1992 Data Month TOTAL AMOUNT DUE  8,579 00 30 13433 1 :i Rose F 2,359 00 30 13443   s 3,845 00 20 18444   s 423 00 30 13445     613 00 30 13446   s 1,134 00 30 18447   s 155 00 Berarflelli 2072957946
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Invoice No  Hr  Andy Pasheluk Brand Manager Lorillard Company 666 Fifth Avenue Nev York, New York 10103 Stephan l ton An A Design Consultant     LION ARTS, INC  1194 HasboroMtoVtlaNo tl Hfeboro B ach  Fla 33062 005 421 4064 PO  Box 32  Southampton  N Y 11966  516  728 2430   Dale January 6, 1986 Our Job No Your P O  No Terms Not thirty days fagjCMe Design Program for the Nev True King Size Filter, Ring Size Menthol, 100 a Filter n d 100  Monthol   Packs and Cartona Out of pocket expenses C 76888 Prl,it C   1 76538 76268 76048 76786 76774 Photo Lettering, Inc i Noi 81623   as per enclosed invoices    169 41 64 95 185 11 37 35 37 80  38,42 Cowp Shop, Inc 1 K0114496 14428 14526 6,593 00 3,910 00 Zx2A4t50 20  handling chargei Total    533 12 203 51 1 8 217 50   18,954 13 3 790 82   22,744 95 TC6T2068
# 6  0S O3 1S94 09:39   a z  as 2127532304  R  PROPERTIES INT L gjk LEO BURNETT U 8A API   ovvxm o  lq hjuctt commny  wt  P ADVERTISING 26 WEST WACKEJl CTIVR  CHICAGO   LLI 0 8 80641   3 J 220 686  SPACE ORDER NO  10PK GAMED  12 MAGAZINE Data 06 11 93 PAGE 1 Advartlaar PHILIP MORRIS INC Contract Year 09 01 93 THRU C8 31 S4 Discount Laval Last tflsney commlsalon 15 CO on you Cash dlaoount 2 00  on nat 10 DAYS To tha publlahar of: GAME DAY MAGAZINE MR  GERALD GERARDIELLO NATIONAL SALES MANAGER NATIONAL FOOTBALL LEAGUE 410 PARK AVENUE NEW YORK NY 10022 DATE SPACE CCLOR BLEED MAIL INVOICE TO: Accounting Oapartmont Saotlon a PRODUCT NOTES VENDOR COST SEP 93 10 SACK COVER 4 C BLEED 10 MARLB0R0 01 161,840 00 POS ED: 1993 SEASON NOTE 01  GAME DAY PACKAGE INCLUDESl OPFICIAL NFL SUPERSOWL XXVI2I GAME DAY FRCGRAK BACK COVER  HAWAII PRO BOWL GAMS DAY PROGRAM SACK COVER  TEAM NFL BACK COVER PLEASE SIGN AND RETURN THE ATTACHED DUPLICATE THU l ACt 0 Dt  II tUIJCCT TO III CCHOTrTlONt HCMON AHO THE AAAA eoaomoia co aicht mi  THU I ACt 0 3tA It IUB ICT TO THI ALIlltMIVI MMUIf T TC l THAT AATI8  mCalOiftO OlfCO HTi   TC, Am W C0 0 MtTV WfTM AWV QOVtM  yinTALiV M oit3 Mi  Hum on moulationi m imict s g tni tun  1 I r aCC onotn, AXr DI ft UAZt ct A r M CCI CHAMID wh h   I   U fll zt f I A 0 Ali  MTf  CTC CDZZZJ UVJl  PUF ur rr t:  r s     r  iur             cvf                   v  r  :           W          A v          ALL     V   iV CL  V   if uOi LL I CUYWfMC UPPu i    OiH   0 r aw AU  tenu ezv mv    i LEO BURNETT U S Ap ORIGINAL 2041597671

# %% [markdown]
# # Setting up SPACY Pipeline
#
# Now we have text information from the xml files. Next step is to extract the entities.
# Using SPACY for extracting relevant information

# %%
import spacy
import spacy.cli
spacy.cli.download("en_core_web_sm")
nlp = spacy.load("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Detecting date and filling it in date dictionary, directly puttin in a 
# series won't work because in case of multiple entry as list it will take only
# the last entry:
date_dict = {}
#invoice_no = {}
customer_name_dict = {}
#total_amt = {}
for i in range(0, df.shape[0]):
  date_list = []
  name_list = []
  text = df.iloc[i,:]
  doc = nlp(str(text))
  for ent in doc.ents:
      if ent.label_ == 'DATE':
          date_list.append(ent.text)
          #date_dict[i] = ent.text
          #df['Date'] = ent.text
      elif ent.label_ == 'PERSON':
          name_list.append(ent.text)

  date_dict[i] = date_list        
  customer_name_dict[i] = name_list

# %% [markdown]
# # Unfiltered Results:
#
# Code above give us the results in the unfiltered form (for ex: date may contain date and some other numbers tagged as date). Now we need to apply several other techniques to filter the results, one is discussed below.

# %%
import pprint
#pprint.pprint(customer_name_dict)
pprint.pprint(date_dict)
# Out:
# {0: ['07025', '30 Days', 'June, 1967'],
#  1: ['THIS 6001', 'July 1', 'Oct 18, 19096'],
#  2: ['2758 3050', '1978'],
#  3: ['10956 5036',
#      '1331 800 767',
#      '9618',
#      '10529',
#      '27408 7018',
#      '07 01 99',
#      '06 01 99 to 06 30 99'],
#  4: ['15206 4490',
#      '15268 0155',
#      '30 DAYS OF INVOICE DATE ARE SUBJECT',
#      'October 26, 1992',
#      'September 1992',
#      '30 13433 1',
#      '423 00 30',
#      '13445',
#      '13446',
#      '1,134 00'],
#  5: ['10103', '2430', 'January 6, 1986', 'thirty days', '81623', '14428 14526'],
#  6: ['O3 1S94', '2127532304', '09 01 93', '1993', '2041597671'],
#  7: ['20044', '19750 3', 'May 19, 1995', 'January 1995'],
#  8: ['24 9', 'FISCAL YEAR'],
#  9: ['10019', '30 DAYS'],
#  10: ['1201',
#       '10178',
#       '352 0102',
#       'January 9, 1991',
#       'January February',
#       '2029377295'],
#  11: ['40202', '1981'],
#  12: ['November 4, 1996', 'November', '2216'],
#  13: ['71 0167'],
#  14: ['October 10, 1991'],
#  15: ['5 1990'],
#  16: ['18674', '23831'],
#  17: ['1350',
#       'APRIL 1983',
#       '101865',
#       '15 1 15',
#       '2004',
#       '32005',
#       '02006',
#       '32007'],
#  18: ['10016 DATE 1 19 79', '2063235029'],
#  19: ['16001',
#       '01 22',
#       '1998',
#       'Five Thousand and 00 100 Dollars',
#       '01 22',
#       '10886',
#       '012298 01 22',
#       '83542431'],
#  20: ['1201', 'December 1990', 'December 19, 1990', '19 90', 'January 9, 1991'],
#  21: ['June 1969', '23 April', '24 April', 'May 1969'],
#  22: ['January 4, 1973', 'October 1 through December 31, 1972', '10 5 72'],
#  23: ['21201', 'August 30, 1994', 'July, 1994'],
#  24: ['1995', '14 81', '2084020376'],
#  25: ['248838 August 27, 1984 Lorillard',
#       '217019',
#       '7019 2 DESCRIPTION',
#       '90 Day'],
#  26: ['August 30, 1904'],
#  27: ['1984', '217011'],
#  28: ['5352', 'MO 20781', 'August  ', '2429 16 TI3168 9150'],
#  29: ['84 1 410105110', 'September October', '0071P'],
#  30: ['May 17, 1993', '10016 5895 INV   ', '1074', '118 1074 Chattanooga 04'],
#  31: ['May 18, 1998'],
#  32: ['Friday, January 19,1996', 'April December 1995', '1996'],
#  33: ['14 83'],
#  34: ['10022',
#       '15710 3512',
#       'DECEMBER',
#       '0151 57',
#       '0008',
#       '017922 11237670\nName'],
#  35: ['02203', '0392274 100', '37010050', '2024483248'],
#  36: ['10050', 'August', 'September 1995', '0505', '1399'],
#  37: ['January 7 7, 1984', 'February 6, 1984 Attention', 'December, 1983'],
#  38: ['10010', '846106'],
#  39: ['1031', '8 1932', '1 0'],
#  40: ['October 24, 1985 230', '2044146550'],
#  41: ['MAY 1 8 1990', '18041', '121008', '1990'],
#  42: ['1201', '20044', 'May 8, 1991', 'Seminar', '202937027J'],
#  43: ['64 988', '14 83', '2084022136'],
#  44: ['7734', '6439', '2030403394'],
#  45: ['DECEMBER', '20P'],
#  46: ['Monday Tuesday', 'Wednesday Thursday Friday   Saturday', 'Sunday'],
#  47: ['0392274 100', '132082 504', '2029138584'],
#  48: ['1111', '10', '59 2764097', '10016 5895', '93089916'],
#  49: ['5068', '8154 April 13, 1994', '2071382979'],
#  50: ['91 7 00', '02 0ct 91', '01 04', '2056446070'],
#  51: ['2003', '94 25', '90 7 43 Date', '28th September, 1988', '26904'],
#  52: ['1404',
#       '22313 1404',
#       '830 0620',
#       '2021',
#       '23261',
#       'October 17, 1994',
#       '1726',
#       'August 18, 1994',
#       'September 12',
#       'September 22',
#       'October 4, 1994',
#       '24 00'],
#  53: ['1300', '1782', '1145', 'OH 44193 1376', 'AUGUST 29TH', 'OH 44193 1376'],
#  54: ['June 9, 1981', '00 204034506'],
#  55: ['27102',
#       '12680',
#       'December 12, 1990',
#       '0019 03 00',
#       'November 1, 1990 through',
#       'November 30, 1990',
#       '5741'],
#  56: [],
#  57: ['1274'],
#  58: ['24 September, 1993', '7 11'],
#  59: ['May 31, 2001', '100583', 'May 2001', '207685', '92891078'],
#  60: ['the month of February, 1991', '1991'],
#  61: ['1002', '00 TOTAL 27450', 'rAlU', '27460 00'],
#  62: ['27102',
#       '09 01 2001',
#       '14 2001',
#       'August 2001',
#       '10 14 2001',
#       '1 33 DAYS',
#       '31 60 DAYS PAST',
#       '61 90 DAYS PAST',
#       '90 DAYS PAST',
#       '700 00 0'],
#  63: ['68144 1800',
#       '7887',
#       'FEB 20 1997',
#       '01R1 26 FEB 97',
#       '1017',
#       '1000P',
#       '1106P',
#       '1806',
#       '7 96'],
#  64: ['60605', '2 10 DAYS FROM DATE OF INVOICE  SPACE', '05 05 05'],
#  65: ['1253'],
#  66: ['27408 April 30, 2001',
#       '100583',
#       'April 2001',
#       '205119',
#       '2001',
#       '15 00 670',
#       '92857672'],
#  67: ['November 16  1992', '5920 1993', '77204'],
#  68: ['6076',
#       'January 8, 1997',
#       '1201',
#       'Monthly',
#       'December 1  31, 1996',
#       '30 days',
#       '1275651 2063610103'],
#  69: ['16 1B 2902', 'OCTOBER 8  2002', '773 63', '0110'],
#  70: ['1998', '39560 3217', '1998', '03 74 1490', 'MARCH', '51999 9902'],
#  71: ['45202',
#       '2838',
#       '40232',
#       'NOVEMBER 7  1988',
#       'September 30',
#       '8 15 88',
#       '9 16 88',
#       '680303607'],
#  72: ['July 28, 1972'],
#  73: ['1201', '20044', 'six working days', '1456'],
#  74: ['August 24, 1994', '98052 3906', '1401 7710 WA01', '1156'],
#  75: ['November 22, 1994', '99206', '1096'],
#  76: ['1602', '6064', 'February 1, 1998 thru January 31, 1999', '10556NW 26'],
#  77: ['1989', 'April 25, 1989', '8000', '2070425084'],
#  78: ['7227',
#       '8011492203303362',
#       '42',
#       'MAY 15,1992',
#       'MAY 8, 1992',
#       '2887',
#       '2023133413'],
#  79: ['25 27100', 'May 19 1992', 'April 1992', '1362'],
#  80: ['1725', 'January and February 2987', '2025019037'],
#  81: ['20004 1206',
#       '3009',
#       'June 30, 2000',
#       'June 30, 2000',
#       'QUARTER ENDING JUNE 30, 2000'],
#  82: ['August 30, 1965'],
#  83: ['25595'],
#  84: ['July 5, 1983', '1532 1'],
#  85: ['10158 1212', 'January, 1997', 'November 30, 1996'],
#  86: ['15719', '15719', '1050 00', '1050'],
#  87: ['00 42', 'September October', '0071P'],
#  88: ['B 1932', '20 61 74'],
#  89: ['3L day',
#       '16 00',
#       '16 00',
#       '14 8',
#       'the end of the next month',
#       '30',
#       '00'],
#  90: ['6543', '10249', '6992910902'],
#  91: ['November 22  1996', '1996 97'],
#  92: ['950 00', '37 13', '9 27 99', '11 30 99', '8829 03', '2080724768'],
#  93: ['1989', '100011 67', '30 days', '1563', '94161 1563'],
#  94: ['10249', '10017', '1 1 78 to 1 1 79'],
#  95: ['May 13, 1998', '2 95', '0370'],
#  96: ['1930',
#       '1932',
#       '1072',
#       '1932',
#       '1420100001 10 VSA2 9021',
#       '1530000001 8'],
#  97: ['MAY 31, 1994', '7 89', '3160'],
#  98: ['29583', '5122', '1560', '2432 89 01', 'July, 1996'],
#  99: ['April 20, 1993', '23831 8100', '1991', '1991', '1991', '4605'],
#  100: ['1201', '20044', '1991', 'June 30, 1991', '564000713'],
#  101: ['10022', '15710 1', 'NOVEMBER, 1979 3,513 00'],
#  102: ['1740'],
#  103: ['5491 April 16, 1973', 'all 1 1118'],
#  104: [],
#  105: ['23831 6100', 'October 10, 1990', '30 Days'],
#  106: ['77058',
#        '486 8815',
#        'May 2,2000',
#        'May 3 2000',
#        'May 5  2000 Review',
#        '450 00',
#        'May 7 2000',
#        'May 8 2000',
#        'May 9 2000 Meeting',
#        '750 00',
#        'May 31',
#        '300 00'],
#  107: ['1515',
#        '7CTI0N 172176',
#        '1396 04',
#        '1146',
#        '1140 6',
#        '1900 00 1930 00',
#        '3525 00 3525 00',
#        '12526',
#        '010474',
#        '810 00'],
#  108: ['January 27  1993', '06831', '3762 85', '40 1992', '6ox 77204'],
#  109: ['06 14 06'],
#  110: ['1556', '10128', '27404', '1903'],
#  111: ['1201', 'August 1992', '2023592499'],
#  112: ['09 22', '1999', '37 13', '2080724769'],
#  113: ['March 3', '2 95', '0431'],
#  114: ['August 23, 2001 PMUSA 28718',
#        '15, 01   ',
#        '01 First Quarter',
#        '01 Second Quarter   ',
#        '01 Third Quarter',
#        '6950'],
#  115: ['Tuesday, February 21, 2000', '00 3', '1551 2085699682'],
#  116: ['44106 7006', 'April 5 1995', '23234'],
#  117: ['November 15', '27102', 'September 1, 1995', 'October 31, 1995'],
#  118: ['7 80', '1831', '15 days', '45 days', '0270', '8 1 81'],
#  119: ['2242',
#        '2146 00340 Date',
#        '20044',
#        'June',
#        '26 50 3975 00',
#        '1507',
#        '1892',
#        'annual',
#        'June 16 18, 1993',
#        '0980'],
#  120: ['September 7, 1983 RECHNUNG', '1983'],
#  121: ['77204', 'February 23  1993', '7720 1', '46270'],
#  122: ['August 25, 1994', '2003', '0048'],
#  123: [],
#  124: ['07118', 'MAY 7   8, 1992'],
#  125: ['24 98', '2425', '04 2763901'],
#  126: ['5400', '23261 6583', '30 DAYS', 'APRIL 19S3'],
#  127: ['14 2899', '7 83', 'June 14, 1983', '1001', '51480 2406'],
#  128: ['0103684',
#        '19805',
#        '7025 DISCH DATE 04 19 94',
#        '15408162',
#        '19720',
#        '1465 00 1465 00',
#        '297 65',
#        '2039 05 2039 05',
#        '45 00',
#        '22188 40 22188 40',
#        '22188 40 22188 40'],
#  129: ['1351',
#        '2420',
#        '8269',
#        'February 12',
#        '1999',
#        '1 12th of 1999',
#        'monthly',
#        'January',
#        '30 days',
#        '86462933'],
#  130: ['October 17, 1994', '00 September 1994'],
#  131: ['8954 11', '465818', '2024476618'],
#  132: ['31 01', '2001', '27404', '3S1 81', '01 1640', '198261'],
#  133: ['October 1, 1995 through March 31, 1996',
#        'November 1, 1995 through March 31, 1996',
#        '230 00'],
#  134: ['8000',
#        'March 11, 1998',
#        '18926 1200',
#        'MO 65105 2118',
#        '2004',
#        '30 days'],
#  135: ['f990', '2 910'],
#  136: ['70', '10017', '1970', '1971'],
#  137: ['01 01 96 TO 12 31 36', '6001', '53 2084022167'],
#  138: ['10017 April 19  1990', '8000'],
#  139: ['1212', '20005 3987', '1163', '2041158049'],
#  140: ['September 8, 1984'],
#  141: ['14 2222 29', '10022', '20 DAYS', 'June 14, 1975 thru', 'June 30, 1975'],
#  142: ['7 19', '82 24'],
#  143: ['5356'],
#  144: [],
#  145: ['10 MARLBORO FEB 1996', 'MAY 1', '2084022300'],
#  146: ['19182'],
#  147: ['009596', '1995', '24 95', '24 95', '1875 00'],
#  148: ['06 06 97 Tobacco Institute State Activities',
#        'Thursday',
#        'Friday Saturday Sunday Monday   ',
#        'Tuesday',
#        '7 50'],
#  149: ['1101 30th', '1988'],
#  150: ['July 21, 1983', 'August 1, 1983 Attention', '1983', 'June, 1983'],
#  151: ['06 19 97',
#        'Thursday',
#        'Friday Saturday Sunday Monday Tuesday',
#        '51828 4421'],
#  152: ['5352', '3770', '1918 91', '9113'],
#  153: ['29583', '5122', '2432 89 01', 'June, 1996'],
#  154: ['the next 24', 'the first one third', '025078 11025096'],
#  155: ['1605', '2344', '12954907'],
#  156: [],
#  157: ['1201', '352 0151', '8, 1991', 'July 25, 1991', 'Three days'],
#  158: ['September 16, 1994', '72801', '0079'],
#  159: ['1044', 'April 30, 1998 S', '7 1M9', '30 days', '4030692', '7462'],
#  160: ['0283'],
#  161: ['February 27, 1989', '21688', '27420', 'March 20, 1989 87803303'],
#  162: ['September 2,1997',
#        '1301',
#        '1942',
#        '1129',
#        '1129',
#        '1100   1129',
#        '83553545'],
#  163: ['FISCAL YEAR'],
#  164: ['December 3, 1998', '119865391', '19 1,7', '24 49', '85'],
#  165: ['May 30, 1989'],
#  166: ['3172 1201109106', '27104', '8730260743'],
#  167: ['June',
#        '20005',
#        'June 30  1998',
#        '910 00 910',
#        '7 95',
#        '8017',
#        '2073883306'],
#  168: ['11572'],
#  169: [],
#  170: ['15206 4490',
#        '15268 0155',
#        '30 DAYS OF INVOICE DATE ARE SUBJECT',
#        '1126415'],
#  171: ['4410', '1998', '10017 5592', 'April 20 23, 1998 Less', '54 1307663'],
#  172: ['10023', '4145', '24 2000 2001817', '24 2000', '29 70', '2085699260'],
#  173: [],
#  174: ['July 22, 1994', '96822'],
#  175: ['60601 1692', '83544771'],
#  176: ['27347',
#        '1770',
#        '04 92',
#        '01 01',
#        '003207 19',
#        '1770',
#        '60127 0347 2029370804'],
#  177: ['the month of November 1993', '0632'],
#  178: ['February 16'],
#  179: ['MAY 28, 1976', '11021', '1975', '76', '14 50', '24 1962'],
#  180: ['27429 919'],
#  181: ['October 2'],
#  182: ['10011'],
#  183: ['October 17, 1994', '33130', '1401 7710'],
#  184: ['10016 5896', '14 94'],
#  185: ['19103 7396 Oct', '23 1392502', '1993'],
#  186: ['Sunday',
#        '15230 0069',
#        '105377 00',
#        '10103 0105377006 0000164363',
#        '85 118200',
#        '85 1 18200 07',
#        '1246',
#        '0 00',
#        '24 28',
#        '21 90'],
#  187: ['26234',
#        'October 19  2001',
#        'November 14,2001',
#        '3281',
#        '01 01 09',
#        '2085539738'],
#  188: [],
#  189: ['10 days'],
#  190: ['13 week', 'Nov  10, 1953'],
#  191: ['1974 1800', '66708', '9205'],
#  192: ['10010', '100070', '5  AD'],
#  193: ['10103', '04 30 87', '7120002350'],
#  194: ['December 23, 1999', '100175', '2801', '0616'],
#  195: ['October 27'],
#  196: ['14 97 1991', 'JAN 1996'],
#  197: ['October 19', '6036494'],
#  198: ['02215'],
#  199: ['April 27, 1993'],
#  200: ['23261',
#        '112676 59573',
#        '01 1st Quarter',
#        '93106 2003',
#        '3854 2085540620'],
#  201: ['March 31, 1976'],
#  202: ['May 19, 1983', 'May 30, 1983 Attention', 'April, 1983'],
#  203: ['1201'],
#  204: ['15476', '77261', '68103'],
#  205: ['1034',
#        '27102',
#        '1515',
#        'June 4, 1984',
#        'July 31',
#        '73 3200',
#        'the period June 4, 1984',
#        'July 31, 1984',
#        '21 years of age'],
#  206: ['01345', '01345', 'August 4, 1989   ', '01345', 'August 4, 1989 Roview'],
#  207: ['1201', '7566', '20044 7566'],
#  208: ['01 01 95 TO 13 31',
#        '1ST',
#        'MAY 34 4SS',
#        'MAY 4 400 00',
#        '1095 12',
#        'MAY 12,400 00 JtBJ 12'],
#  209: ['April 3  1996 PM', '1373', '1 27', '15 DAYS FROM DATE'],
#  210: ['10044', '12011', '2023591606'],
#  211: ['10010', '4828', '2 2041532206'],
#  212: ['9,6 1994'],
#  213: ['10038', '7 61'],
#  214: ['9 DATE May 15, 1991', 'April 2 4, 1991'],
#  215: ['October 1981', '2040345058'],
#  216: ['1201',
#        '4002',
#        'May 31, 1991',
#        'February 21, 1991',
#        'April and May 1991',
#        '2029370308'],
#  217: ['August 20, 1981', '27420', '20031', '3536 00921466\nName'],
#  218: ['24114', '2 95', '0316'],
#  219: ['2 3 33 PH', '27102 73786', '85 00 85', '1991'],
#  220: ['April 10,2001',
#        '27602',
#        '8145',
#        '6778',
#        'April 10,2001',
#        '1860827 52645 0292'],
#  221: ['October 24, 1994', '32302', '1401 7710', '0260'],
#  222: ['November 5', 'November 1997'],
#  223: ['10022', '5211', 'August 4, 1975', 'July 31', '1600 00', '6298 10'],
#  224: ['6375',
#        '01 28 97',
#        'Tuesday',
#        'Thursday',
#        'Friday',
#        'Sunday Monday 03 Feb 97',
#        'Jan 97 01 Feb 97',
#        '88 0000 9070',
#        '2927'],
#  225: ['216454 688'],
#  226: ['21688', '27420', '806523', '10198', '0001'],
#  227: ['November',
#        'January, 1969',
#        '20 days',
#        'December',
#        'January',
#        '1969',
#        '1969 62 000      2'],
#  228: ['29520', '1401', '2 95', '640 0238'],
#  229: ['May 26  1992', '0229', '77204'],
#  230: ['1401 7710 WA 01', '2rt 5', '0992'],
#  231: ['001123', '1999'],
#  232: ['01 01 9C', '11 08', '2084022076'],
#  233: ['October 19  2001', '25234', '6036494', '06 01 01', '09 30'],
#  234: ['49 Date 12 12 971'],
#  235: ['23831', '0979014D', '2030138139'],
#  236: ['1201', '38, 1990', 'Tuesday, October 2, 1990', 'One day'],
#  237: ['7665',
#        'Monday Tuesday',
#        'Thursday',
#        'Fr day',
#        'Saturday Sunday',
#        'Feb 97',
#        '97 22',
#        '24730',
#        '24 00'],
#  238: ['May 23,1992', '04 90 305 9070'],
#  239: ['SEP QUARTER', '2084022143'],
#  240: ['six months', '2042529'],
#  241: ['1404',
#        '22313 1404',
#        '83641620',
#        '2021',
#        '23261',
#        '1719',
#        'November 14, 1994',
#        '021238 071',
#        'November 28, 1994',
#        '22314'],
#  242: ['3RD QUARTER 1993'],
#  243: ['21688', '27420', '001 1112 02', '8331257'],
#  244: ['34605', '8415', '2934', '10 2037023778'],
#  245: ['10019 February 20, 1995', 'January 1995', '74 10', 'January 1995'],
#  246: ['60693', '60601', '82 01 15'],
#  247: ['1201', '20044', 'the month of May, 1989', '0 00'],
#  248: ['March 30, 1964', 'March 10, 1964', '2531 13'],
#  249: ['1975', '1975', '1974', '112477', '922741'],
#  250: ['1,300 00 0'],
#  251: ['July 30,1969', 'March,April 1969'],
#  252: ['01 06 1998', '01 06 1998 1210', '83554921'],
#  253: [],
#  254: ['76 98', '1977', '1300 00 1300', '19 00', '20 2797 20', '1 2197'],
#  255: ['3464 00'],
#  256: ['2003', '2229'],
#  257: [],
#  258: ['27102', 'October 15,1996', '51496', '7102'],
#  259: ['September 1, 1996',
#        '21688',
#        '27420',
#        'September',
#        'monthly',
#        '1996',
#        '2216',
#        '86619053'],
#  260: [],
#  261: ['56 1758927', 'August, 1997'],
#  262: ['05 28', '052985 2878KA 96958', '377 94 053085', '024267'],
#  263: ['8011', 'August 23rd, 1976', '5132', 'AUGUST 16TH, 1976'],
#  264: ['9 4 May 31', '1990'],
#  265: ['A DECEMBER 2, 1992'],
#  266: ['14 1957', '02R2 27 FEB 97'],
#  267: ['3530', '11572', 'S3RS8l', '4370', '3160'],
#  268: ['1932', '1940', '3145'],
#  269: ['10022 5702', '05 0245', '15 0404', '1424', '1675 45', '6208U66'],
#  270: ['May 1990',
#        '100015 27',
#        '30 days',
#        '3 per month',
#        '1281',
#        '1563',
#        '2044348020'],
#  271: ['1300', 'October 26, 1990', 'September 1990', '10311341 2015003772'],
#  272: ['August 30, 1978', 'Soptenber 1978'],
#  273: ['07 12', '20N'],
#  274: ['May 23,1994', 'June 8,1994', 'more than 30 days', '2 weeks'],
#  275: ['18285 00', '2225 00', '2650', '1 619126902'],
#  276: ['1996', '24 84', '14 83 2084022482'],
#  277: [],
#  278: ['0009', '21688', '27420', '20988', '10239', '230 0001'],
#  279: ['1201 Pennsylvania Ave',
#        'March 1991',
#        '7 70',
#        '7 00',
#        '4 25',
#        '20007',
#        'TI0091 1106\nName'],
#  280: ['July 26, 1990', '1611', '37 15'],
#  281: ['27102',
#        '27102',
#        'MARCH 16 20  1987',
#        'FIVE DAYS',
#        'MARCH 13, 1987',
#        '0798'],
#  282: ['1992'],
#  283: ['43278'],
#  284: ['May 31, 1982', 'December 31, 1981'],
#  285: ['JUNE 2 7, 1073', '10022', '14', '30 50'],
#  286: ['07 12'],
#  287: ['1201',
#        '24010 03 DATE August 25, 1997',
#        'June and July 1997',
#        'July',
#        'July 1997'],
#  288: ['0562',
#        '6060',
#        '1301',
#        '98101 September 30, 1998',
#        'the period ending',
#        '2 55',
#        '83542445'],
#  289: ['531210', '1ST MONTH'],
#  290: ['27864',
#        '27864',
#        '5141 Facsdioe',
#        'December 1,1998',
#        'the month of November 1998',
#        'May 22, 1997',
#        '49 30'],
#  291: ['64105 December 23, 1991', '44 0585497', '29973', 'this past month'],
#  292: ['April 27, 1992', '34 1992'],
#  293: ['Mosaic 2001 2001', '27404', '198261', '9 28571'],
#  294: ['03 14 07', '04 4 63 2084021796\nName'],
#  295: ['September', '1995', '08229', '14 95'],
#  296: ['Wednesday 6th October 1993',
#        'Wednesday 22nd September',
#        'Thursday 23rd September',
#        '10012',
#        '2346 8U96EE'],
#  297: ['August', '1994', 'August, 1995', '10022', '12210', '2601', '1032'],
#  298: ['60601 21C4', 'August 7, 1996 Service and Production', '5,627 20'],
#  299: [],
#  300: [],
#  301: ['27106', '93000 30'],
#  302: ['fFAP   910', '21 88'],
#  303: ['60004', 'August 14 1995', '1995', 'the last one third'],
#  304: ['01 01 1999',
#        '01 15 1999',
#        '35656 01',
#        '35689 01',
#        '00   36440',
#        '79   36411',
#        '00   36416',
#        '72   36418',
#        '90   36457',
#        '53   36420',
#        '80   36424'],
#  305: ['22306 107515', '21 87', 'THE 20TH DAY', '107515', '10 days'],
#  306: ['1 00', '5225 0C'],
#  307: [],
#  308: ['February 19, 1993', 'the month of January, 1993'],
#  309: ['July 27, 1994', '47375', '1401 7710'],
#  310: ['2044694612'],
#  311: ['August 24, 1994', '1401 7710 WA01', '1155'],
#  312: ['10310 5201', '2001', '27404'],
#  313: ['1201', '20044', '20  1991', 'February 21, 1991', '2029377724'],
#  314: ['49 221 2030917', '2520 00', '1602', '00', '2026000623'],
#  315: ['1201', '20044', 'Dec  1, 1997', 'October 1997'],
#  316: ['March 8, 1984',
#        'February 1, 1984 to February 29, 1984',
#        '15 00',
#        '156774'],
#  317: ['24 75'],
#  318: ['1742100043 31 0325 0000039384', '9096'],
#  319: ['20006', 'July 20, 1981', 'April 1 through June 30, 1981', '03724950'],
#  320: ['06831', 'January 27, 1992', '2552 85', '77204'],
#  321: ['1998', 'November 18, 1998', '1148', '23 7979'],
#  322: ['October 1, 1996', 'the month of October, 1996', '1061'],
#  323: ['February 6', 'February 6, 1982', 'May 16, 1982', '25 34'],
#  324: ['2203 3033621', '1587 00 1507 00', '1587 00'],
#  325: ['10016 5895', 'March 1, 1994 iwvcKTfNO'],
#  326: ['OCTOBER 1964', '22162 55', '18838 17 01 64'],
#  327: ['09 96 1991', '1996', '2084022805'],
#  328: ['CAST 17', 'August 17, 1970', 'the month of July,', '1970'],
#  329: ['1886'],
#  330: ['January 9', 'March 15'],
#  331: ['11563', '11 19 74'],
#  332: ['15710 1', 'OCTOBER, 1979', '017347 11237695'],
#  333: ['11419', '1515', '11375', '2902'],
#  334: ['9A January 2, 1994', '2041388921'],
#  335: ['1100', '10418 December 16, 1987'],
#  336: ['23261 l i S',
#        'December 9  1995',
#        '4 quarter',
#        '1V034S',
#        '2003000  2001213573'],
#  337: ['3949', '55402 April 30, 1997', '00 75 00'],
#  338: ['12309 Date', '23 DECEMBER 1986'],
#  339: ['10017, December 20'],
#  340: ['October 31, 1994', '1401 7710'],
#  341: ['CHICAGO', 'JULY 21, 1941'],
#  342: ['10022 5702', '11 0313', '30 100377'],
#  343: ['1981', '2618', '2618'],
#  344: ['July 21, 1994', '96804'],
#  345: ['3400', '2506S', '21688', '27420', '6130', '20988'],
#  346: ['2030015848'],
#  347: ['26603 2000', '6040', '4th quarter 1987'],
#  348: ['04 14 83 2084022002'],
#  349: ['DECEMBER 20, 1951', '100 00', 'January 10, 1952'],
#  350: ['40 West 23rd', '10010', '100070', '25991'],
#  351: ['2393', 'M11985 date October 10, 1990'],
#  352: ['1330', '15309226', '1310', '51849 2684'],
#  353: ['Wednesday Thursday',
#        'Friday Saturday Sunday   Monday Tuesday',
#        '97 09',
#        'Oct 97',
#        '7 31'],
#  354: ['2003', '2003', '1999', '2403 91', '1999', '2003'],
#  355: ['19033',
#        '01 01 76 TO 01 01',
#        '2490252 595187',
#        '2886168 840196 540509',
#        '4266873 3',
#        '2884122 840196 540509',
#        '4264827 4',
#        '1020902'],
#  356: ['77204', 'December 16  1992', '1038C', '77204'],
#  357: ['06 31', '10390', '77204'],
#  358: ['OH 43216 Date', '1983'],
#  359: ['thirty days', '2222'],
#  360: ['4683', '10004', 'March 22,1994'],
#  361: ['1984', '211593', '1593 1'],
#  362: ['August 1, 1984 LORILLARD', '211596', '1596 2', '14 Day', '5050'],
#  363: ['1973', '000579'],
#  364: ['1030', 'May 9, 1975', '1530', '20852'],
#  365: ['FEB 1996 QUARTER', '14 63', '2084021870'],
#  366: ['010951'],
#  367: ['10017 705007 008000 PAGE NB6 01',
#        '03 31',
#        '2815480 8',
#        '1382 00 1937',
#        '1382 ee 1937 ee 1382 0'],
#  368: ['10022', '20 DAYS', 'monthly', '31 75'],
#  369: ['20814',
#        'October 86',
#        '27102',
#        'one quarter',
#        'August 23, to October 23, 1986 Period'],
#  370: ['June 1, 1971'],
#  371: ['2003', 'December 1985'],
#  372: ['OH 4363',
#        'Floor 3',
#        'September 30, 1988',
#        'monthly',
#        '30 days',
#        'annual',
#        '50856 0943'],
#  373: ['5052 27',
#        '03 01 84 013617',
#        'MARCH 1984',
#        '20810 70',
#        '3121 61 17689 09',
#        '01 84 000001 90909916'],
#  374: ['1998', '83565210'],
#  375: ['1 2080272310'],
#  376: ['100015 34', '1281', '1563', '2044348035'],
#  377: ['Sep 92'],
#  378: ['August 1, 1984', '14 Day'],
#  379: ['the period ending September 30, 1994'],
#  380: ['0069300 8 9', '3988009'],
#  381: ['1 7', 'lTRPRESS 104518', '7 7  ', '14075 4068 4 ENGRAVING', '4645 62'],
#  382: ['MAY JON QUARTER', 'SEP QUARTER', '2084022243'],
#  383: ['6152413934', '100259', '23261', '23261'],
#  384: ['June',
#        '20005',
#        'June 30, 1998',
#        '198261',
#        '40176',
#        '221 00 895',
#        '2073883308'],
#  385: ['5201', '25234', 'January 03', '45490', '3313'],
#  386: ['Date 30 AUGUST 1985', '2044402070'],
#  387: ['10022 August 27, 1982',
#        '126502',
#        '126503',
#        '126504 1',
#        '126650',
#        '017957'],
#  388: ['3530',
#        '11572',
#        '1609',
#        'December 31, 1992',
#        '4370',
#        'This Period',
#        '3100'],
#  389: ['April 25  1988 Statement 99916197',
#        '0134S',
#        '020 March 17 24  1988 Roviow',
#        'January 21  1988',
#        'February 25,26, 1988 Review'],
#  390: ['JULY 20, 1993'],
#  391: ['1821', '60601', '7 1992', '1993', 'February 0'],
#  392: ['10017'],
#  393: ['2203 303362', '130141', '1181 04', 'fftuhO 2026000180'],
#  394: ['01 16 01 18', '0047', '12 28 6425', '01 18 01 0003 004'],
#  395: ['June 10  1991', '4490'],
#  396: ['1989', '1002 22359', '01 24'],
#  397: ['15493 7361AM', 'December 31, 1992'],
#  398: ['2380', '3530', '1474', '2 68', '1151', '1255', '3160'],
#  399: ['2219 1100 17tn',
#        '20036',
#        '2566',
#        '0047998',
#        '7 9',
#        'MONDAY',
#        '6062524',
#        'DAILY',
#        '147350',
#        '6062524'],
#  400: ['23261', '1330', 'May 14, 1991', '0305992'],
#  401: ['70821 3197',
#        'May 19, 1997',
#        '16218',
#        '5075 13151',
#        'April 30, 1997',
#        '30 DAYS PAST',
#        '0 00 60 DAYS PAST',
#        '00 90 DAYS PAST',
#        '120  DAYS PAST'],
#  402: ['06531', 'May 26  1992', '77204'],
#  403: ['1129', '2 5 1997', '1 65', '8355'],
#  404: ['1050', '2505123539'],
#  405: ['15372638'],
#  406: ['September 11, 1985 6Mp'],
#  407: [],
#  408: ['10022 6250',
#        '16, 1992',
#        'May 1992',
#        'May 19, 1992',
#        'April 14, 1992   ',
#        '24 16',
#        '01345',
#        'May 20, 1992',
#        '2501336275'],
#  409: ['23224A', '22  1994', '20 days'],
#  410: ['October 19, 1994', '1401 7710', '0407'],
#  411: ['27102', 'June 6 1991', '1002 20 00', '1991'],
#  412: ['1040  8160',
#        'December 27  1988',
#        '4th quarter 1988',
#        '81703',
#        '200fflLZ 20010020'],
#  413: ['August 9, 19B4', '27102', '7 26 84', 'MO'],
#  414: ['1201',
#        '20044',
#        '22010',
#        '0151',
#        '30, 1991 1',
#        'monthly',
#        'September 1991'],
#  415: ['1522', '1548', '21', '15 3 30', '1064'],
#  416: [],
#  417: ['07 12 36', '06 1', 'Q3 2084022128'],
#  418: ['6088', 'February 28, 1994', '30 DAYS'],
#  419: ['00', '88EISflI 8fi'],
#  420: ['March 12, 1984', '25157r', '1575 3', '14 10,17oT5o', '00920576'],
#  421: ['01 01 96 TO 12 31 96 DATE 11 08', '09 13 96', '1096', '228 90'],
#  422: ['05 QUARTER'],
#  423: ['05001', '30091 4100', '23831', '250ML 12'],
#  424: ['1975 1976', '38 7 43 2', '1975', '1976', '005091', '2063233533'],
#  425: ['6959', '11510654', '2042356681'],
#  426: ['10016 5802', '93503', '3503'],
#  427: ['May 2, 1980', '1 56'],
#  428: ['27404'],
#  429: ['October 6, 1998 Client', '1860 2080972555'],
#  430: ['29583', '1560', '2432 89'],
#  431: ['07751798 43081', 'OH 45501', 'OH 937', '52463', '0313'],
#  432: ['24 95',
#        '28265 12C',
#        '7930',
#        '28265 1206',
#        '30 DAYS',
#        '7596',
#        '3215',
#        '803682 1140',
#        '12120 00'],
#  433: ['24 69', '0071430'],
#  434: ['December 11, 1973', '20006', '2015064568'],
#  435: ['27102 1325 REQUISITION', '2955'],
#  436: ['7511'],
#  437: ['3536', 'July 18, 1984', '7001 1 DESCRIPTION', '14 0ay', '5050'],
#  438: ['10016', 'December 8  1990 Time', '33145'],
#  439: ['21688', '27405', '6130', '20988', '10847', '2300001'],
#  440: ['3880 5 April',
#        'March 1983',
#        'March 1983',
#        '1933',
#        '32 v',
#        '2001207817'],
#  441: ['10016 6895', '9 1 1995', '1995'],
#  442: ['July 27, 1976', '011517 11231261'],
#  443: ['8271',
#        '22090 3705 June 30, 1995',
#        '26583',
#        '23261 6583',
#        'the month of June, 1995',
#        '4220'],
#  444: ['27102'],
#  445: ['3063153', '1143', '53547 1148 s', '1 00'],
#  446: ['56 1758927'],
#  447: ['27102', 'Six weeks weeks', '50641 3423'],
#  448: ['23831 8100'],
#  449: ['60605',
#        '1039016 10016',
#        '2 10 DAYS FROM DATE OF INVOICE  SPACE ONLY  DAY'],
#  450: ['September 20, 1994', '0857'],
#  451: ['30719 8017 DATE',
#        'OCTOBER 12  1993 TWO GATEFOLD FOUR',
#        'NOVEMBER 2  1993 ONE 1 3',
#        '30813',
#        'NOVEMBER 2  1993 ONE PAGE FOUR',
#        '50 jf 92204693'],
#  452: ['1201', '1992', 'February 21, 1991', 'March 1992'],
#  453: ['83j', 'February 1,1998', '27404', 'February', '1410', '86618995'],
#  454: ['2003',
#        'No 20 8749 Date',
#        '28th April, 1989',
#        '26904 0996',
#        'amonHmnnt 1',
#        '40'],
#  455: ['1998', '20044', '7566', '1998', '1998', '1998', '9058'],
#  456: ['4376'],
#  457: ['May 4, 1989'],
#  458: ['1201',
#        '20044',
#        'Dec  10, 1990',
#        'September 30, 1990',
#        '3413 00 1311',
#        '680709486'],
#  459: ['September',
#        '99999999',
#        '99999 99999',
#        '40440 40450',
#        '40460',
#        '100s B8G2F LESS CCWP CIOTS CAMB LTS',
#        '1008',
#        '100s B8G2P LESS CCMP',
#        '1008',
#        '2080272271'],
#  460: ['October 17, 1994', '0152'],
#  461: ['39238', '2 95', '0027'],
#  462: ['18', '1954', 'May, 1954'],
#  463: ['10010 5201 INVOICE DATE N0V24 99', '10529', '221672', '86087318'],
#  464: ['1999', '27404', '198261', '43 PR05 001125', '86087420'],
#  465: ['1995',
#        '23261',
#        'the month of September, 1995',
#        '13 19',
#        '16 19 00',
#        '7 19 00 133'],
#  466: ['33030'],
#  467: ['19044', '443 8710', 'JUNE 20, 1988', '27420', 'JUNE 20, 1988', '19044'],
#  468: ['31 0320', '96063482'],
#  469: ['FISCAL YEAR:'],
#  470: ['April 28,1992', 'April 27', '2303'],
#  471: ['March 22nd 1994', '20 38 09'],
#  472: ['1201',
#        '20044',
#        '4021',
#        '14, 1991',
#        'the week of May 20, 1991',
#        'Eight days',
#        '40 36',
#        '19 27',
#        '2029378060'],
#  473: ['2706 April 30, 1993', '2071386322'],
#  474: ['27113', 'July', '50659 3709'],
#  475: ['1401 7710 OR', '2 95'],
#  476: ['21688', '27420', '1082', '9883'],
#  477: ['1201', '14, 1991', 'Four days'],
#  478: [],
#  479: ['1996', '788 43', '2084022347'],
#  480: ['January 21,2002',
#        '49551',
#        'October 1,2001 TO December 31,2001',
#        'Quarterly'],
#  481: ['February 23, 1996',
#        '4282 000230',
#        'February 23, 1996',
#        '4282 000230',
#        '28290 5615'],
#  482: ['23235', '2 95'],
#  483: ['15206 4490',
#        '10016',
#        '30 DAYS OF INVOICE DATE ARE SUBJECT',
#        '1126415',
#        'August 11, 1993',
#        'JULY 1993',
#        '30 18151  June 1993',
#        '18157  June 1993'],
#  484: ['10487', '10017', '10038 P 18858', '10487'],
#  485: ['April 5  1994'],
#  486: ['January 27, 1984', 'February 6, 1984 Attention', 'December, 1983'],
#  487: ['026211', '1401'],
#  488: ['10022', '15710', '00 APRIL', '1980'],
#  489: ['6608', '1401', '0099'],
#  490: ['23927', '2 95'],
#  491: ['1998', 'June 20  1998', 'May 15,1998', '0096'],
#  492: ['2235', '20634', '30 DAYS', '14 16', '46 48', '24 26', '45', '3040 00'],
#  493: ['1201', '313929 12th July 1992'],
#  494: ['May 7,2002', '7004', '9181'],
#  495: ['110270313W', '3012215', '37010050'],
#  496: ['23234', '1 59280', 'November 13 2001', '6527', '6036494W'],
#  497: ['June 18, 1993',
#        '10016 5895 INV',
#        '1089',
#        '24 93',
#        '19200 00',
#        '07632   1201 461 6700',
#        '1201 461'],
#  498: ['March 30, 1989', '21688', '27420 1688', 'April 20, 1989'],
#  499: ['27405'],
#  500: ['December 9, 1992', '1 1 1992', '1802 04', '9309', '30 DAYS'],
#  501: ['January 28, 1983', 'February 7, 1983 Attention', 'December, 1982'],
#  502: ['1109', 'January 2, 1991 1990', 'DECEMBER 21, 1990'],
#  503: ['October 2, 1998', '2 95', '0498'],
#  504: ['DKC1S 99', '1999', '86087317'],
#  505: ['19750 3 DATE May 19, 1995', 'December 1994'],
#  506: ['1003 7 0000'],
#  507: ['August 12,1998', '1483'],
#  508: ['50787 6895'],
#  509: ['Sunday', 'Wednesday Thursday', 'Friday I Saturday', '00 2755', '2 55'],
#  510: ['14039', '18 97 027009', '1640 0164'],
#  511: ['July 1,1991'],
#  512: ['April 15, 2002',
#        '100583',
#        'March 2002',
#        '80239',
#        '2002',
#        '2973',
#        '2363',
#        '92873320'],
#  513: ['04 0392',
#        '27102 0000 JOB',
#        '31, 1987',
#        '33095',
#        '74 33895',
#        '65 70',
#        '6033',
#        '24349 92',
#        '24349 92',
#        '24349 92',
#        '24349 92',
#        '24 2312',
#        '24 2312',
#        '23APRS7 26714'],
#  514: ['November 13  1996',
#        'the month of October 1996',
#        'September 1996',
#        '0381'],
#  515: ['1996 1 926'],
#  516: ['October 22, 2001', '14 01', '27,995 00'],
#  517: ['0392274 100', '37080040', '70 50198', '132082 504', '37010050'],
#  518: ['April   June 1974', '2359 44', '1974', '2501367970'],
#  519: ['07025', '30 Days', 'June, 1967'],
#  520: ['THIS 6001', 'July 1', 'Oct 18, 19096'],
#  521: ['2758 3050', '1978'],
#  522: ['10956 5036',
#        '1331 800 767',
#        '9618',
#        '10529',
#        '27408 7018',
#        '07 01 99',
#        '06 01 99 to 06 30 99'],
#  523: ['15206 4490',
#        '15268 0155',
#        '30 DAYS OF INVOICE DATE ARE SUBJECT',
#        'October 26, 1992',
#        'September 1992',
#        '30 13433 1',
#        '423 00 30',
#        '13445',
#        '13446',
#        '1,134 00'],
#  524: ['10103',
#        '2430',
#        'January 6, 1986',
#        'thirty days',
#        '81623',
#        '14428 14526'],
#  525: ['O3 1S94', '2127532304', '09 01 93', '1993', '2041597671'],
#  526: ['20044', '19750 3', 'May 19, 1995', 'January 1995'],
#  527: ['24 9', 'FISCAL YEAR'],
#  528: ['10019', '30 DAYS'],
#  529: ['1201',
#        '10178',
#        '352 0102',
#        'January 9, 1991',
#        'January February',
#        '2029377295'],
#  530: ['40202', '1981'],
#  531: ['November 4, 1996', 'November', '2216'],
#  532: ['71 0167'],
#  533: ['October 10, 1991'],
#  534: ['5 1990'],
#  535: ['18674', '23831'],
#  536: ['1350',
#        'APRIL 1983',
#        '101865',
#        '15 1 15',
#        '2004',
#        '32005',
#        '02006',
#        '32007'],
#  537: ['10016 DATE 1 19 79', '2063235029'],
#  538: ['16001',
#        '01 22',
#        '1998',
#        'Five Thousand and 00 100 Dollars',
#        '01 22',
#        '10886',
#        '012298 01 22',
#        '83542431'],
#  539: ['1201',
#        'December 1990',
#        'December 19, 1990',
#        '19 90',
#        'January 9, 1991'],
#  540: ['June 1969', '23 April', '24 April', 'May 1969'],
#  541: ['January 4, 1973', 'October 1 through December 31, 1972', '10 5 72'],
#  542: ['21201', 'August 30, 1994', 'July, 1994'],
#  543: ['1995', '14 81', '2084020376'],
#  544: ['248838 August 27, 1984 Lorillard',
#        '217019',
#        '7019 2 DESCRIPTION',
#        '90 Day'],
#  545: ['August 30, 1904'],
#  546: ['1984', '217011'],
#  547: ['5352', 'MO 20781', 'August  ', '2429 16 TI3168 9150'],
#  548: ['84 1 410105110', 'September October', '0071P'],
#  549: ['May 17, 1993', '10016 5895 INV   ', '1074', '118 1074 Chattanooga 04'],
#  550: ['May 18, 1998'],
#  551: ['Friday, January 19,1996', 'April December 1995', '1996'],
#  552: ['14 83'],
#  553: ['10022',
#        '15710 3512',
#        'DECEMBER',
#        '0151 57',
#        '0008',
#        '017922 11237670\nName'],
#  554: ['02203', '0392274 100', '37010050', '2024483248'],
#  555: ['10050', 'August', 'September 1995', '0505', '1399'],
#  556: ['January 7 7, 1984', 'February 6, 1984 Attention', 'December, 1983'],
#  557: ['10010', '846106'],
#  558: ['1031', '8 1932', '1 0'],
#  559: ['October 24, 1985 230', '2044146550'],
#  560: ['MAY 1 8 1990', '18041', '121008', '1990'],
#  561: ['1201', '20044', 'May 8, 1991', 'Seminar', '202937027J'],
#  562: ['64 988', '14 83', '2084022136'],
#  563: ['7734', '6439', '2030403394'],
#  564: ['DECEMBER', '20P'],
#  565: ['Monday Tuesday', 'Wednesday Thursday Friday   Saturday', 'Sunday'],
#  566: ['0392274 100', '132082 504', '2029138584'],
#  567: ['1111', '10', '59 2764097', '10016 5895', '93089916'],
#  568: ['5068', '8154 April 13, 1994', '2071382979'],
#  569: ['91 7 00', '02 0ct 91', '01 04', '2056446070'],
#  570: ['2003', '94 25', '90 7 43 Date', '28th September, 1988', '26904'],
#  571: ['1404',
#        '22313 1404',
#        '830 0620',
#        '2021',
#        '23261',
#        'October 17, 1994',
#        '1726',
#        'August 18, 1994',
#        'September 12',
#        'September 22',
#        'October 4, 1994',
#        '24 00'],
#  572: ['1300', '1782', '1145', 'OH 44193 1376', 'AUGUST 29TH', 'OH 44193 1376'],
#  573: ['June 9, 1981', '00 204034506'],
#  574: ['27102',
#        '12680',
#        'December 12, 1990',
#        '0019 03 00',
#        'November 1, 1990 through',
#        'November 30, 1990',
#        '5741'],
#  575: [],
#  576: ['1274'],
#  577: ['24 September, 1993', '7 11'],
#  578: ['May 31, 2001', '100583', 'May 2001', '207685', '92891078'],
#  579: ['the month of February, 1991', '1991'],
#  580: ['1002', '00 TOTAL 27450', 'rAlU', '27460 00'],
#  581: ['27102',
#        '09 01 2001',
#        '14 2001',
#        'August 2001',
#        '10 14 2001',
#        '1 33 DAYS',
#        '31 60 DAYS PAST',
#        '61 90 DAYS PAST',
#        '90 DAYS PAST',
#        '700 00 0'],
#  582: ['68144 1800',
#        '7887',
#        'FEB 20 1997',
#        '01R1 26 FEB 97',
#        '1017',
#        '1000P',
#        '1106P',
#        '1806',
#        '7 96'],
#  583: ['60605', '2 10 DAYS FROM DATE OF INVOICE  SPACE', '05 05 05'],
#  584: ['1253'],
#  585: ['27408 April 30, 2001',
#        '100583',
#        'April 2001',
#        '205119',
#        '2001',
#        '15 00 670',
#        '92857672'],
#  586: ['November 16  1992', '5920 1993', '77204'],
#  587: ['6076',
#        'January 8, 1997',
#        '1201',
#        'Monthly',
#        'December 1  31, 1996',
#        '30 days',
#        '1275651 2063610103'],
#  588: ['16 1B 2902', 'OCTOBER 8  2002', '773 63', '0110'],
#  589: ['1998', '39560 3217', '1998', '03 74 1490', 'MARCH', '51999 9902'],
#  590: ['45202',
#        '2838',
#        '40232',
#        'NOVEMBER 7  1988',
#        'September 30',
#        '8 15 88',
#        '9 16 88',
#        '680303607'],
#  591: ['July 28, 1972'],
#  592: ['1201', '20044', 'six working days', '1456'],
#  593: ['August 24, 1994', '98052 3906', '1401 7710 WA01', '1156'],
#  594: ['November 22, 1994', '99206', '1096'],
#  595: ['1602', '6064', 'February 1, 1998 thru January 31, 1999', '10556NW 26'],
#  596: ['1989', 'April 25, 1989', '8000', '2070425084'],
#  597: ['7227',
#        '8011492203303362',
#        '42',
#        'MAY 15,1992',
#        'MAY 8, 1992',
#        '2887',
#        '2023133413'],
#  598: ['25 27100', 'May 19 1992', 'April 1992', '1362'],
#  599: ['1725', 'January and February 2987', '2025019037'],
#  600: ['20004 1206',
#        '3009',
#        'June 30, 2000',
#        'June 30, 2000',
#        'QUARTER ENDING JUNE 30, 2000'],
#  601: ['August 30, 1965'],
#  602: ['25595'],
#  603: ['July 5, 1983', '1532 1'],
#  604: ['10158 1212', 'January, 1997', 'November 30, 1996'],
#  605: ['15719', '15719', '1050 00', '1050'],
#  606: ['00 42', 'September October', '0071P'],
#  607: ['B 1932', '20 61 74'],
#  608: ['3L day',
#        '16 00',
#        '16 00',
#        '14 8',
#        'the end of the next month',
#        '30',
#        '00'],
#  609: ['6543', '10249', '6992910902'],
#  610: ['November 22  1996', '1996 97'],
#  611: ['950 00', '37 13', '9 27 99', '11 30 99', '8829 03', '2080724768'],
#  612: ['1989', '100011 67', '30 days', '1563', '94161 1563'],
#  613: ['10249', '10017', '1 1 78 to 1 1 79'],
#  614: ['May 13, 1998', '2 95', '0370'],
#  615: ['1930',
#        '1932',
#        '1072',
#        '1932',
#        '1420100001 10 VSA2 9021',
#        '1530000001 8'],
#  616: ['MAY 31, 1994', '7 89', '3160'],
#  617: ['29583', '5122', '1560', '2432 89 01', 'July, 1996'],
#  618: ['April 20, 1993', '23831 8100', '1991', '1991', '1991', '4605'],
#  619: ['1201', '20044', '1991', 'June 30, 1991', '564000713'],
#  620: ['10022', '15710 1', 'NOVEMBER, 1979 3,513 00'],
#  621: ['1740'],
#  622: ['5491 April 16, 1973', 'all 1 1118'],
#  623: [],
#  624: ['23831 6100', 'October 10, 1990', '30 Days'],
#  625: ['77058',
#        '486 8815',
#        'May 2,2000',
#        'May 3 2000',
#        'May 5  2000 Review',
#        '450 00',
#        'May 7 2000',
#        'May 8 2000',
#        'May 9 2000 Meeting',
#        '750 00',
#        'May 31',
#        '300 00'],
#  626: ['1515',
#        '7CTI0N 172176',
#        '1396 04',
#        '1146',
#        '1140 6',
#        '1900 00 1930 00',
#        '3525 00 3525 00',
#        '12526',
#        '010474',
#        '810 00'],
#  627: ['January 27  1993', '06831', '3762 85', '40 1992', '6ox 77204'],
#  628: ['06 14 06'],
#  629: ['1556', '10128', '27404', '1903'],
#  630: ['1201', 'August 1992', '2023592499'],
#  631: ['09 22', '1999', '37 13', '2080724769'],
#  632: ['March 3', '2 95', '0431'],
#  633: ['August 23, 2001 PMUSA 28718',
#        '15, 01   ',
#        '01 First Quarter',
#        '01 Second Quarter   ',
#        '01 Third Quarter',
#        '6950'],
#  634: ['Tuesday, February 21, 2000', '00 3', '1551 2085699682'],
#  635: ['44106 7006', 'April 5 1995', '23234'],
#  636: ['November 15', '27102', 'September 1, 1995', 'October 31, 1995'],
#  637: ['7 80', '1831', '15 days', '45 days', '0270', '8 1 81'],
#  638: ['2242',
#        '2146 00340 Date',
#        '20044',
#        'June',
#        '26 50 3975 00',
#        '1507',
#        '1892',
#        'annual',
#        'June 16 18, 1993',
#        '0980'],
#  639: ['September 7, 1983 RECHNUNG', '1983'],
#  640: ['77204', 'February 23  1993', '7720 1', '46270'],
#  641: ['August 25, 1994', '2003', '0048'],
#  642: [],
#  643: ['07118', 'MAY 7   8, 1992'],
#  644: ['24 98', '2425', '04 2763901'],
#  645: ['5400', '23261 6583', '30 DAYS', 'APRIL 19S3'],
#  646: ['14 2899', '7 83', 'June 14, 1983', '1001', '51480 2406'],
#  647: ['0103684',
#        '19805',
#        '7025 DISCH DATE 04 19 94',
#        '15408162',
#        '19720',
#        '1465 00 1465 00',
#        '297 65',
#        '2039 05 2039 05',
#        '45 00',
#        '22188 40 22188 40',
#        '22188 40 22188 40'],
#  648: ['1351',
#        '2420',
#        '8269',
#        'February 12',
#        '1999',
#        '1 12th of 1999',
#        'monthly',
#        'January',
#        '30 days',
#        '86462933'],
#  649: ['October 17, 1994', '00 September 1994'],
#  650: ['8954 11', '465818', '2024476618'],
#  651: ['31 01', '2001', '27404', '3S1 81', '01 1640', '198261'],
#  652: ['October 1, 1995 through March 31, 1996',
#        'November 1, 1995 through March 31, 1996',
#        '230 00'],
#  653: ['8000',
#        'March 11, 1998',
#        '18926 1200',
#        'MO 65105 2118',
#        '2004',
#        '30 days'],
#  654: ['f990', '2 910'],
#  655: ['70', '10017', '1970', '1971'],
#  656: ['01 01 96 TO 12 31 36', '6001', '53 2084022167'],
#  657: ['10017 April 19  1990', '8000'],
#  658: ['1212', '20005 3987', '1163', '2041158049'],
#  659: ['September 8, 1984'],
#  660: ['14 2222 29', '10022', '20 DAYS', 'June 14, 1975 thru', 'June 30, 1975'],
#  661: ['7 19', '82 24'],
#  662: ['5356'],
#  663: [],
#  664: ['10 MARLBORO FEB 1996', 'MAY 1', '2084022300'],
#  665: ['19182'],
#  666: ['009596', '1995', '24 95', '24 95', '1875 00'],
#  667: ['06 06 97 Tobacco Institute State Activities',
#        'Thursday',
#        'Friday Saturday Sunday Monday   ',
#        'Tuesday',
#        '7 50'],
#  668: ['1101 30th', '1988'],
#  669: ['July 21, 1983', 'August 1, 1983 Attention', '1983', 'June, 1983'],
#  670: ['06 19 97',
#        'Thursday',
#        'Friday Saturday Sunday Monday Tuesday',
#        '51828 4421'],
#  671: ['5352', '3770', '1918 91', '9113'],
#  672: ['29583', '5122', '2432 89 01', 'June, 1996'],
#  673: ['the next 24', 'the first one third', '025078 11025096'],
#  674: ['1605', '2344', '12954907'],
#  675: [],
#  676: ['1201', '352 0151', '8, 1991', 'July 25, 1991', 'Three days'],
#  677: ['September 16, 1994', '72801', '0079'],
#  678: ['1044', 'April 30, 1998 S', '7 1M9', '30 days', '4030692', '7462'],
#  679: ['0283'],
#  680: ['February 27, 1989', '21688', '27420', 'March 20, 1989 87803303'],
#  681: ['September 2,1997',
#        '1301',
#        '1942',
#        '1129',
#        '1129',
#        '1100   1129',
#        '83553545'],
#  682: ['FISCAL YEAR'],
#  683: ['December 3, 1998', '119865391', '19 1,7', '24 49', '85'],
#  684: ['May 30, 1989'],
#  685: ['3172 1201109106', '27104', '8730260743'],
#  686: ['June',
#        '20005',
#        'June 30  1998',
#        '910 00 910',
#        '7 95',
#        '8017',
#        '2073883306'],
#  687: ['11572'],
#  688: [],
#  689: ['15206 4490',
#        '15268 0155',
#        '30 DAYS OF INVOICE DATE ARE SUBJECT',
#        '1126415'],
#  690: ['4410', '1998', '10017 5592', 'April 20 23, 1998 Less', '54 1307663'],
#  691: ['10023', '4145', '24 2000 2001817', '24 2000', '29 70', '2085699260'],
#  692: [],
#  693: ['July 22, 1994', '96822'],
#  694: ['60601 1692', '83544771'],
#  695: ['27347',
#        '1770',
#        '04 92',
#        '01 01',
#        '003207 19',
#        '1770',
#        '60127 0347 2029370804'],
#  696: ['the month of November 1993', '0632'],
#  697: ['February 16'],
#  698: ['MAY 28, 1976', '11021', '1975', '76', '14 50', '24 1962'],
#  699: ['27429 919'],
#  700: ['October 2'],
#  701: ['10011'],
#  702: ['October 17, 1994', '33130', '1401 7710'],
#  703: ['10016 5896', '14 94'],
#  704: ['19103 7396 Oct', '23 1392502', '1993'],
#  705: ['Sunday',
#        '15230 0069',
#        '105377 00',
#        '10103 0105377006 0000164363',
#        '85 118200',
#        '85 1 18200 07',
#        '1246',
#        '0 00',
#        '24 28',
#        '21 90'],
#  706: ['26234',
#        'October 19  2001',
#        'November 14,2001',
#        '3281',
#        '01 01 09',
#        '2085539738'],
#  707: [],
#  708: ['10 days'],
#  709: ['13 week', 'Nov  10, 1953'],
#  710: ['1974 1800', '66708', '9205'],
#  711: ['10010', '100070', '5  AD'],
#  712: ['10103', '04 30 87', '7120002350'],
#  713: ['December 23, 1999', '100175', '2801', '0616'],
#  714: ['October 27'],
#  715: ['14 97 1991', 'JAN 1996'],
#  716: ['October 19', '6036494'],
#  717: ['02215'],
#  718: ['April 27, 1993'],
#  719: ['23261',
#        '112676 59573',
#        '01 1st Quarter',
#        '93106 2003',
#        '3854 2085540620'],
#  720: ['March 31, 1976'],
#  721: ['May 19, 1983', 'May 30, 1983 Attention', 'April, 1983'],
#  722: ['1201'],
#  723: ['15476', '77261', '68103'],
#  724: ['1034',
#        '27102',
#        '1515',
#        'June 4, 1984',
#        'July 31',
#        '73 3200',
#        'the period June 4, 1984',
#        'July 31, 1984',
#        '21 years of age'],
#  725: ['01345', '01345', 'August 4, 1989   ', '01345', 'August 4, 1989 Roview'],
#  726: ['1201', '7566', '20044 7566'],
#  727: ['01 01 95 TO 13 31',
#        '1ST',
#        'MAY 34 4SS',
#        'MAY 4 400 00',
#        '1095 12',
#        'MAY 12,400 00 JtBJ 12'],
#  728: ['April 3  1996 PM', '1373', '1 27', '15 DAYS FROM DATE'],
#  729: ['10044', '12011', '2023591606'],
#  730: ['10010', '4828', '2 2041532206'],
#  731: ['9,6 1994'],
#  732: ['10038', '7 61'],
#  733: ['9 DATE May 15, 1991', 'April 2 4, 1991'],
#  734: ['October 1981', '2040345058'],
#  735: ['1201',
#        '4002',
#        'May 31, 1991',
#        'February 21, 1991',
#        'April and May 1991',
#        '2029370308'],
#  736: ['August 20, 1981', '27420', '20031', '3536 00921466\nName'],
#  737: ['24114', '2 95', '0316'],
#  738: ['2 3 33 PH', '27102 73786', '85 00 85', '1991'],
#  739: ['April 10,2001',
#        '27602',
#        '8145',
#        '6778',
#        'April 10,2001',
#        '1860827 52645 0292'],
#  740: ['October 24, 1994', '32302', '1401 7710', '0260'],
#  741: ['November 5', 'November 1997'],
#  742: ['10022', '5211', 'August 4, 1975', 'July 31', '1600 00', '6298 10'],
#  743: ['6375',
#        '01 28 97',
#        'Tuesday',
#        'Thursday',
#        'Friday',
#        'Sunday Monday 03 Feb 97',
#        'Jan 97 01 Feb 97',
#        '88 0000 9070',
#        '2927'],
#  744: ['216454 688'],
#  745: ['21688', '27420', '806523', '10198', '0001'],
#  746: ['November',
#        'January, 1969',
#        '20 days',
#        'December',
#        'January',
#        '1969',
#        '1969 62 000      2'],
#  747: ['29520', '1401', '2 95', '640 0238'],
#  748: ['May 26  1992', '0229', '77204'],
#  749: ['1401 7710 WA 01', '2rt 5', '0992'],
#  750: ['001123', '1999'],
#  751: ['01 01 9C', '11 08', '2084022076'],
#  752: ['October 19  2001', '25234', '6036494', '06 01 01', '09 30'],
#  753: ['49 Date 12 12 971'],
#  754: ['23831', '0979014D', '2030138139'],
#  755: ['1201', '38, 1990', 'Tuesday, October 2, 1990', 'One day'],
#  756: ['7665',
#        'Monday Tuesday',
#        'Thursday',
#        'Fr day',
#        'Saturday Sunday',
#        'Feb 97',
#        '97 22',
#        '24730',
#        '24 00'],
#  757: ['May 23,1992', '04 90 305 9070'],
#  758: ['SEP QUARTER', '2084022143'],
#  759: ['six months', '2042529'],
#  760: ['1404',
#        '22313 1404',
#        '83641620',
#        '2021',
#        '23261',
#        '1719',
#        'November 14, 1994',
#        '021238 071',
#        'November 28, 1994',
#        '22314'],
#  761: ['3RD QUARTER 1993'],
#  762: ['21688', '27420', '001 1112 02', '8331257'],
#  763: ['34605', '8415', '2934', '10 2037023778'],
#  764: ['10019 February 20, 1995', 'January 1995', '74 10', 'January 1995'],
#  765: ['60693', '60601', '82 01 15'],
#  766: ['1201', '20044', 'the month of May, 1989', '0 00'],
#  767: ['March 30, 1964', 'March 10, 1964', '2531 13'],
# ...
#  786: ['3530', '11572', 'S3RS8l', '4370', '3160'],
#  787: ['1932', '1940', '3145'],
#  788: ['10022 5702', '05 0245', '15 0404', '1424', '1675 45', '6208U66'],
#  789: ['May 1990',
#        '100015 27',
#        '30 days',
#        '3 per month',
#        '1281',
#        '1563',
#        '2044348020'],
#  790: ['1300', 'October 26, 1990', 'September 1990', '10311341 2015003772'],
#  791: ['August 30, 1978', 'Soptenber 1978'],
#  792: ['07 12', '20N'],
#  793: ['May 23,1994', 'June 8,1994', 'more than 30 days', '2 weeks'],
#  794: ['18285 00', '2225 00', '2650', '1 619126902'],
#  795: ['1996', '24 84', '14 83 2084022482'],
#  796: [],
#  797: ['0009', '21688', '27420', '20988', '10239', '230 0001'],
#  798: ['1201 Pennsylvania Ave',
#        'March 1991',
#        '7 70',
#        '7 00',
#        '4 25',
#        '20007',
#        'TI0091 1106\nName'],
#  799: ['July 26, 1990', '1611', '37 15'],
#  800: ['27102',
#        '27102',
#        'MARCH 16 20  1987',
#        'FIVE DAYS',
#        'MARCH 13, 1987',
#        '0798'],
#  801: ['1992'],
#  802: ['43278'],
#  803: ['May 31, 1982', 'December 31, 1981'],
#  804: ['JUNE 2 7, 1073', '10022', '14', '30 50'],
#  805: ['07 12'],
#  806: ['1201',
#        '24010 03 DATE August 25, 1997',
#        'June and July 1997',
#        'July',
#        'July 1997'],
#  807: ['0562',
#        '6060',
#        '1301',
#        '98101 September 30, 1998',
#        'the period ending',
#        '2 55',
#        '83542445'],
#  808: ['531210', '1ST MONTH'],
#  809: ['27864',
#        '27864',
#        '5141 Facsdioe',
#        'December 1,1998',
#        'the month of November 1998',
#        'May 22, 1997',
#        '49 30'],
#  810: ['64105 December 23, 1991', '44 0585497', '29973', 'this past month'],
#  811: ['April 27, 1992', '34 1992'],
#  812: ['Mosaic 2001 2001', '27404', '198261', '9 28571'],
#  813: ['03 14 07', '04 4 63 2084021796\nName'],
#  814: ['September', '1995', '08229', '14 95'],
#  815: ['Wednesday 6th October 1993',
#        'Wednesday 22nd September',
#        'Thursday 23rd September',
#        '10012',
#        '2346 8U96EE'],
#  816: ['August', '1994', 'August, 1995', '10022', '12210', '2601', '1032'],
#  817: ['60601 21C4', 'August 7, 1996 Service and Production', '5,627 20'],
#  818: [],
#  819: [],
#  820: ['27106', '93000 30'],
#  821: ['fFAP   910', '21 88'],
#  822: ['60004', 'August 14 1995', '1995', 'the last one third'],
#  823: ['01 01 1999',
#        '01 15 1999',
#        '35656 01',
#        '35689 01',
#        '00   36440',
#        '79   36411',
#        '00   36416',
#        '72   36418',
#        '90   36457',
#        '53   36420',
#        '80   36424'],
#  824: ['22306 107515', '21 87', 'THE 20TH DAY', '107515', '10 days'],
#  825: ['1 00', '5225 0C'],
#  826: [],
#  827: ['February 19, 1993', 'the month of January, 1993'],
#  828: ['July 27, 1994', '47375', '1401 7710'],
#  829: ['2044694612'],
#  830: ['August 24, 1994', '1401 7710 WA01', '1155'],
#  831: ['10310 5201', '2001', '27404'],
#  832: ['1201', '20044', '20  1991', 'February 21, 1991', '2029377724'],
#  833: ['49 221 2030917', '2520 00', '1602', '00', '2026000623'],
#  834: ['1201', '20044', 'Dec  1, 1997', 'October 1997'],
#  835: ['March 8, 1984',
#        'February 1, 1984 to February 29, 1984',
#        '15 00',
#        '156774'],
#  836: ['24 75'],
#  837: ['1742100043 31 0325 0000039384', '9096'],
#  838: ['20006', 'July 20, 1981', 'April 1 through June 30, 1981', '03724950'],
#  839: ['06831', 'January 27, 1992', '2552 85', '77204'],
#  840: ['1998', 'November 18, 1998', '1148', '23 7979'],
#  841: ['October 1, 1996', 'the month of October, 1996', '1061'],
#  842: ['February 6', 'February 6, 1982', 'May 16, 1982', '25 34'],
#  843: ['2203 3033621', '1587 00 1507 00', '1587 00'],
#  844: ['10016 5895', 'March 1, 1994 iwvcKTfNO'],
#  845: ['OCTOBER 1964', '22162 55', '18838 17 01 64'],
#  846: ['09 96 1991', '1996', '2084022805'],
#  847: ['CAST 17', 'August 17, 1970', 'the month of July,', '1970'],
#  848: ['1886'],
#  849: ['January 9', 'March 15'],
#  850: ['11563', '11 19 74'],
#  851: ['15710 1', 'OCTOBER, 1979', '017347 11237695'],
#  852: ['11419', '1515', '11375', '2902'],
#  853: ['9A January 2, 1994', '2041388921'],
#  854: ['1100', '10418 December 16, 1987'],
#  855: ['23261 l i S',
#        'December 9  1995',
#        '4 quarter',
#        '1V034S',
#        '2003000  2001213573'],
#  856: ['3949', '55402 April 30, 1997', '00 75 00'],
#  857: ['12309 Date', '23 DECEMBER 1986'],
#  858: ['10017, December 20'],
#  859: ['October 31, 1994', '1401 7710'],
#  860: ['CHICAGO', 'JULY 21, 1941'],
#  861: ['10022 5702', '11 0313', '30 100377'],
#  862: ['1981', '2618', '2618'],
#  863: ['July 21, 1994', '96804'],
#  864: ['3400', '2506S', '21688', '27420', '6130', '20988'],
#  865: ['2030015848'],
#  866: ['26603 2000', '6040', '4th quarter 1987'],
#  867: ['04 14 83 2084022002'],
#  868: ['DECEMBER 20, 1951', '100 00', 'January 10, 1952'],
#  869: ['40 West 23rd', '10010', '100070', '25991'],
#  870: ['2393', 'M11985 date October 10, 1990'],
#  871: ['1330', '15309226', '1310', '51849 2684'],
#  872: ['Wednesday Thursday',
#        'Friday Saturday Sunday   Monday Tuesday',
#        '97 09',
#        'Oct 97',
#        '7 31'],
#  873: ['2003', '2003', '1999', '2403 91', '1999', '2003'],
#  874: ['19033',
#        '01 01 76 TO 01 01',
#        '2490252 595187',
#        '2886168 840196 540509',
#        '4266873 3',
#        '2884122 840196 540509',
#        '4264827 4',
#        '1020902'],
#  875: ['77204', 'December 16  1992', '1038C', '77204'],
#  876: ['06 31', '10390', '77204'],
#  877: ['OH 43216 Date', '1983'],
#  878: ['thirty days', '2222'],
#  879: ['4683', '10004', 'March 22,1994'],
#  880: ['1984', '211593', '1593 1'],
#  881: ['August 1, 1984 LORILLARD', '211596', '1596 2', '14 Day', '5050'],
#  882: ['1973', '000579'],
#  883: ['1030', 'May 9, 1975', '1530', '20852'],
#  884: ['FEB 1996 QUARTER', '14 63', '2084021870'],
#  885: ['010951'],
#  886: ['10017 705007 008000 PAGE NB6 01',
#        '03 31',
#        '2815480 8',
#        '1382 00 1937',
#        '1382 ee 1937 ee 1382 0'],
#  887: ['10022', '20 DAYS', 'monthly', '31 75'],
#  888: ['20814',
#        'October 86',
#        '27102',
#        'one quarter',
#        'August 23, to October 23, 1986 Period'],
#  889: ['June 1, 1971'],
#  890: ['2003', 'December 1985'],
#  891: ['OH 4363',
#        'Floor 3',
#        'September 30, 1988',
#        'monthly',
#        '30 days',
#        'annual',
#        '50856 0943\nName'],
#  892: ['5052 27',
#        '03 01 84 013617',
#        'MARCH 1984',
#        '20810 70',
#        '3121 61 17689 09',
#        '01 84 000001 90909916'],
#  893: ['1998', '83565210'],
#  894: ['1 2080272310'],
#  895: ['100015 34', '1281', '1563', '2044348035'],
#  896: ['Sep 92'],
#  897: ['August 1, 1984', '14 Day'],
#  898: ['the period ending September 30, 1994'],
#  899: ['0069300 8 9', '3988009'],
#  900: ['1 7', 'lTRPRESS 104518', '7 7  ', '14075 4068 4 ENGRAVING', '4645 62'],
#  901: ['MAY JON QUARTER', 'SEP QUARTER', '2084022243'],
#  902: ['6152413934', '100259', '23261', '23261'],
#  903: ['June',
#        '20005',
#        'June 30, 1998',
#        '198261',
#        '40176',
#        '221 00 895',
#        '2073883308'],
#  904: ['5201', '25234', 'January 03', '45490', '3313'],
#  905: ['Date 30 AUGUST 1985', '2044402070'],
#  906: ['10022 August 27, 1982',
#        '126502',
#        '126503',
#        '126504 1',
#        '126650',
#        '017957'],
#  907: ['3530',
#        '11572',
#        '1609',
#        'December 31, 1992',
#        '4370',
#        'This Period',
#        '3100'],
#  908: ['April 25  1988 Statement 99916197',
#        '0134S',
#        '020 March 17 24  1988 Roviow',
#        'January 21  1988',
#        'February 25,26, 1988 Review'],
#  909: ['JULY 20, 1993'],
#  910: ['1821', '60601', '7 1992', '1993', 'February 0'],
#  911: ['10017'],
#  912: ['2203 303362', '130141', '1181 04', 'fftuhO 2026000180'],
#  913: ['01 16 01 18', '0047', '12 28 6425', '01 18 01 0003 004'],
#  914: ['June 10  1991', '4490'],
#  915: ['1989', '1002 22359', '01 24'],
#  916: ['15493 7361AM', 'December 31, 1992'],
#  917: ['2380', '3530', '1474', '2 68', '1151', '1255', '3160'],
#  918: ['2219 1100 17tn',
#        '20036',
#        '2566',
#        '0047998',
#        '7 9',
#        'MONDAY',
#        '6062524',
#        'DAILY',
#        '147350',
#        '6062524'],
#  919: ['23261', '1330', 'May 14, 1991', '0305992'],
#  920: ['70821 3197',
#        'May 19, 1997',
#        '16218',
#        '5075 13151',
#        'April 30, 1997',
#        '30 DAYS PAST',
#        '0 00 60 DAYS PAST',
#        '00 90 DAYS PAST',
#        '120  DAYS PAST'],
#  921: ['06531', 'May 26  1992', '77204'],
#  922: ['1129', '2 5 1997', '1 65', '8355'],
#  923: ['1050', '2505123539'],
#  924: ['15372638'],
#  925: ['September 11, 1985 6Mp'],
#  926: [],
#  927: ['10022 6250',
#        '16, 1992',
#        'May 1992',
#        'May 19, 1992',
#        'April 14, 1992   ',
#        '24 16',
#        '01345',
#        'May 20, 1992',
#        '2501336275'],
#  928: ['23224A', '22  1994', '20 days'],
#  929: ['October 19, 1994', '1401 7710', '0407'],
#  930: ['27102', 'June 6 1991', '1002 20 00', '1991'],
#  931: ['1040  8160',
#        'December 27  1988',
#        '4th quarter 1988',
#        '81703',
#        '200fflLZ 20010020'],
#  932: ['August 9, 19B4', '27102', '7 26 84', 'MO'],
#  933: ['1201',
#        '20044',
#        '22010',
#        '0151',
#        '30, 1991 1',
#        'monthly',
#        'September 1991'],
#  934: ['1522', '1548', '21', '15 3 30', '1064'],
#  935: [],
#  936: ['07 12 36', '06 1', 'Q3 2084022128'],
#  937: ['6088', 'February 28, 1994', '30 DAYS'],
#  938: ['00', '88EISflI 8fi'],
#  939: ['March 12, 1984', '25157r', '1575 3', '14 10,17oT5o', '00920576'],
#  940: ['01 01 96 TO 12 31 96 DATE 11 08', '09 13 96', '1096', '228 90'],
#  941: ['05 QUARTER'],
#  942: ['05001', '30091 4100', '23831', '250ML 12'],
#  943: ['1975 1976', '38 7 43 2', '1975', '1976', '005091', '2063233533'],
#  944: ['6959', '11510654', '2042356681'],
#  945: ['10016 5802', '93503', '3503'],
#  946: ['May 2, 1980', '1 56'],
#  947: ['27404'],
#  948: ['October 6, 1998 Client', '1860 2080972555'],
#  949: ['29583', '1560', '2432 89'],
#  950: ['07751798 43081', 'OH 45501', 'OH 937', '52463', '0313'],
#  951: ['24 95',
#        '28265 12C',
#        '7930',
#        '28265 1206',
#        '30 DAYS',
#        '7596',
#        '3215',
#        '803682 1140',
#        '12120 00'],
#  952: ['24 69', '0071430'],
#  953: ['December 11, 1973', '20006', '2015064568'],
#  954: ['27102 1325 REQUISITION', '2955'],
#  955: ['7511'],
#  956: ['3536', 'July 18, 1984', '7001 1 DESCRIPTION', '14 0ay', '5050'],
#  957: ['10016', 'December 8  1990 Time', '33145'],
#  958: ['21688', '27405', '6130', '20988', '10847', '2300001'],
#  959: ['3880 5 April',
#        'March 1983',
#        'March 1983',
#        '1933',
#        '32 v',
#        '2001207817'],
#  960: ['10016 6895', '9 1 1995', '1995'],
#  961: ['July 27, 1976', '011517 11231261'],
#  962: ['8271',
#        '22090 3705 June 30, 1995',
#        '26583',
#        '23261 6583',
#        'the month of June, 1995',
#        '4220'],
#  963: ['27102'],
#  964: ['3063153', '1143', '53547 1148 s', '1 00'],
#  965: ['56 1758927'],
#  966: ['27102', 'Six weeks weeks', '50641 3423'],
#  967: ['23831 8100'],
#  968: ['60605',
#        '1039016 10016',
#        '2 10 DAYS FROM DATE OF INVOICE  SPACE ONLY  DAY'],
#  969: ['September 20, 1994', '0857'],
#  970: ['30719 8017 DATE',
#        'OCTOBER 12  1993 TWO GATEFOLD FOUR',
#        'NOVEMBER 2  1993 ONE 1 3',
#        '30813',
#        'NOVEMBER 2  1993 ONE PAGE FOUR',
#        '50 jf 92204693'],
#  971: ['1201', '1992', 'February 21, 1991', 'March 1992'],
#  972: ['83j', 'February 1,1998', '27404', 'February', '1410', '86618995'],
#  973: ['2003',
#        'No 20 8749 Date',
#        '28th April, 1989',
#        '26904 0996',
#        'amonHmnnt 1',
#        '40'],
#  974: ['1998', '20044', '7566', '1998', '1998', '1998', '9058'],
#  975: ['4376'],
#  976: ['May 4, 1989'],
#  977: ['1201',
#        '20044',
#        'Dec  10, 1990',
#        'September 30, 1990',
#        '3413 00 1311',
#        '680709486'],
#  978: ['September',
#        '99999999',
#        '99999 99999',
#        '40440 40450',
#        '40460',
#        '100s B8G2F LESS CCWP CIOTS CAMB LTS',
#        '1008',
#        '100s B8G2P LESS CCMP',
#        '1008',
#        '2080272271'],
#  979: ['October 17, 1994', '0152'],
#  980: ['39238', '2 95', '0027'],
#  981: ['18', '1954', 'May, 1954'],
#  982: ['10010 5201 INVOICE DATE N0V24 99', '10529', '221672', '86087318'],
#  983: ['1999', '27404', '198261', '43 PR05 001125', '86087420'],
#  984: ['1995',
#        '23261',
#        'the month of September, 1995',
#        '13 19',
#        '16 19 00',
#        '7 19 00 133'],
#  985: ['33030'],
#  986: ['19044', '443 8710', 'JUNE 20, 1988', '27420', 'JUNE 20, 1988', '19044'],
#  987: ['31 0320', '96063482'],
#  988: ['FISCAL YEAR:'],
#  989: ['April 28,1992', 'April 27', '2303'],
#  990: ['March 22nd 1994', '20 38 09'],
#  991: ['1201',
#        '20044',
#        '4021',
#        '14, 1991',
#        'the week of May 20, 1991',
#        'Eight days',
#        '40 36',
#        '19 27',
#        '2029378060'],
#  992: ['2706 April 30, 1993', '2071386322'],
#  993: ['27113', 'July', '50659 3709'],
#  994: ['1401 7710 OR', '2 95'],
#  995: ['21688', '27420', '1082', '9883'],
#  996: ['1201', '14, 1991', 'Four days'],
#  997: [],
#  998: ['1996', '788 43', '2084022347'],
#  999: ['January 21,2002',
#        '49551',
#        'October 1,2001 TO December 31,2001',
#        'Quarterly'],
#  1000: ['February 23, 1996',
#         '4282 000230',
#         'February 23, 1996',
#         '4282 000230',
#         '28290 5615'],
#  1001: ['23235', '2 95', '1001'],
#  1002: ['15206 4490',
#         '10016',
#         '30 DAYS OF INVOICE DATE ARE SUBJECT',
#         '1126415',
#         'August 11, 1993',
#         'JULY 1993',
#         '30 18151  June 1993',
#         '18157  June 1993',
#         '1002'],
#  1003: ['10487', '10017', '10038 P 18858', '10487', '1003'],
#  1004: ['April 5  1994', '1004'],
#  1005: ['January 27, 1984',
#         'February 6, 1984 Attention',
#         'December, 1983',
#         '1005'],
#  1006: ['026211', '1401', '1006'],
#  1007: ['10022', '15710', '00 APRIL', '1980', '1007'],
#  1008: ['6608', '1401', '0099', '1008'],
#  1009: ['23927', '2 95', '1009'],
#  1010: ['1998', 'June 20  1998', 'May 15,1998', '0096', '1010'],
#  1011: ['2235', '20634', '30 DAYS', '14 16', '46 48', '24 26', '45', '3040 00'],
#  1012: ['1201', '313929 12th July 1992', '1012'],
#  1013: ['May 7,2002', '7004', '9181', '1013'],
#  1014: ['110270313W', '3012215', '37010050', '1014'],
#  1015: ['23234', '1 59280', 'November 13 2001', '6527', '6036494W', '1015'],
#  1016: ['June 18, 1993',
#         '10016 5895 INV',
#         '1089',
#         '24 93',
#         '19200 00',
#         '07632   1201 461 6700',
#         '1201 461',
#         '1016'],
#  1017: ['March 30, 1989', '21688', '27420 1688', 'April 20, 1989', '1017'],
#  1018: ['27405', '1018'],
#  1019: ['December 9, 1992', '1 1 1992', '1802 04', '9309', '30 DAYS', '1019'],
#  1020: ['January 28, 1983',
#         'February 7, 1983 Attention',
#         'December, 1982',
#         '1020'],
#  1021: ['1109', 'January 2, 1991 1990', 'DECEMBER 21, 1990', '1021'],
#  1022: ['October 2, 1998', '2 95', '0498', '1022'],
#  1023: ['DKC1S 99', '1999', '86087317', '1023'],
#  1024: ['19750 3 DATE May 19, 1995', 'December 1994', '1024'],
#  1025: ['1003 7 0000', '1025'],
#  1026: ['August 12,1998', '1483', '1026'],
#  1027: ['50787 6895', '1027'],
#  1028: ['Sunday',
#         'Wednesday Thursday',
#         'Friday I Saturday',
#         '00 2755',
#         '2 55',
#         '1028'],
#  1029: ['14039', '18 97 027009', '1640 0164'],
#  1030: ['July 1,1991', '1030'],
#  1031: ['April 15, 2002',
#         '100583',
#         'March 2002',
#         '80239',
#         '2002',
#         '2973',
#         '2363',
#         '92873320',
#         '1031'],
#  1032: ['04 0392',
#         '27102 0000 JOB',
#         '31, 1987',
#         '33095',
#         '74 33895',
#         '65 70',
#         '6033',
#         '24349 92',
#         '24349 92',
#         '24349 92',
#         '24349 92',
#         '24 2312',
#         '24 2312',
#         '23APRS7 26714',
#         '1032'],
#  1033: ['November 13  1996',
#         'the month of October 1996',
#         'September 1996',
#         '0381',
#         '1033'],
#  1034: ['1996 1 926', '1034'],
#  1035: ['October 22, 2001', '14 01', '27,995 00', '1035'],
#  1036: ['0392274 100', '37080040', '70 50198', '132082 504', '37010050'],
#  1037: ['April   June 1974', '2359 44', '1974', '2501367970', '1037']}

# %% [markdown]
# # POC for filtering results:
#
# Following code shows how by applying pipeline in series a result can be filtered out. Several random values assigned as dates in the previous result are assigned as 'CARDINAL' value here. It shows how a result can be filtered using the pipeline in series. Here we have used same pipeline for better result a different pipeline (different) model should be used.

# %%
stopper = 0
for key in date_dict:
    stopper += 1
    print(key)
    print(date_dict[key])
    for iter in range(0,len(date_dict[key])):
        token = date_dict[key][iter]
        doc = nlp(str(token))
        for ent in doc.ents:
          print(ent.text, ent.label_)
    if stopper > 2:
      break
    print('******************************************************************************************')
# Out:
# 0
# ['07025', '30 Days', 'June, 1967']
# 07025 DATE
# 30 Days DATE
# June, 1967 DATE
# ******************************************************************************************
# 1
# ['THIS 6001', 'July 1', 'Oct 18, 19096']
# 6001 DATE
# July 1 DATE
# 19096 DATE
# ******************************************************************************************
# 2
# ['2758 3050', '1978']
# 2758 3050 DATE
# 1978 DATE

# %% [markdown]
# # Matching the custom patterns
#
# Loading the spacy Matcher and making a matcher object from it. The pattern to be matched can be added to 'matcher' and the 'matcher' object can be applied to the spacy doc (containing thet text data) inorder to match with the customized patterns.

# %%
from spacy.matcher import Matcher
nlp = spacy.load("en_core_web_sm")
matcher = Matcher(nlp.vocab, validate=True)
df[0].astype('string')
print(type(df.iloc[5][0]))
# Out:
# <class 'str'>

# %% [markdown]
# # Call_back function

# %%
date_pattern3 = [{'LOWER':{"REGEX":'^jan|^feb|^mar|^apr|^may|^jun|^jul|^aug|^sep|^oct|^nov|^dec'}},{'LOWER':{'REGEX':'\d{1,2}'}},{'LOWER':{'REGEX':'\d{0-4}'}}]
date_pattern4 = [{'LOWER':{"IN":['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec']}}]


matcher.add('Custom_Date', [date_pattern4])
doc = nlp(df.iloc[i][0])
matches = matcher(doc)
matches

for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]
    span = doc[start:end]
    #print(match_id, string_id, start, end, span.text)
    print(start, end, span.text)

# %%
date_pattern1 = [{'LOWER':{"REGEX":'(jan|feb|mar|apr|may|jun|jul|aug|sep|oct|nov|dec)'}},{}]
                           

def callback_method(matcher, doc, i, matches):
    match_id, start, end = matches[i]
    entity = doc[start:end]
    print(entity.text)
    
matcher = Matcher(nlp.vocab)
matcher.add('Date_Cust2', [date_pattern1], on_match = callback_method)
doc = nlp(df.iloc[5][0])
matcher(doc)
# Out:
# Hfeboro B
# January 6
# [(3056582165036000932, 36, 38), (3056582165036000932, 62, 64)]

# %% [markdown]
# **Hope this helps you to start with the data set and gives you an idea about what to do and how to do. Do share your amazing ideas and methods for entity extraction from such files.**
